# %% [markdown]
# <a href="https://colab.research.google.com/github/niltonsainz/clipping/blob/main/Clipping_FACIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SISTEMA DE CLIPPING LEGISLATIVO - FACIAP
# Versão 1.0 - Câmara dos Deputados e Senado Federal

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from datetime import datetime, timedelta
import re
from urllib.parse import urljoin, urlparse

class NewsClippingSystem:
    def __init__(self):
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        self.data_limite = datetime(2025, 7, 1)  # 01/07/2025
        self.noticias_coletadas = []
        # Removido sistema de duplicatas conforme solicitado pelo usuário

    def parse_date_camara(self, date_string):
        """Converte data da Câmara (17/07/2025 15:31) para datetime"""
        try:
            return datetime.strptime(date_string.strip(), '%d/%m/%Y %H:%M')
        except ValueError:
            try:
                return datetime.strptime(date_string.strip(), '%d/%m/%Y')
            except ValueError:
                return None

    def parse_date_senado(self, date_string):
        """Converte data do Senado (17/07/2025 15h34) para datetime"""
        try:
            # Remove 'h' e substitui por ':'
            date_clean = date_string.strip().replace('h', ':')
            return datetime.strptime(date_clean, '%d/%m/%Y %H:%M')
        except ValueError:
            try:
                # Tenta só a data
                date_only = date_string.split()[0]
                return datetime.strptime(date_only, '%d/%m/%Y')
            except ValueError:
                return None

    def is_date_valid(self, news_date):
        """Verifica se a data da notícia é posterior a 01/07/2025"""
        if news_date is None:
            return False
        return news_date >= self.data_limite

    def testar_paginacao_senado_corrigida(self):
        """
        Testa a paginação correta do Senado baseada nos prints fornecidos
        """
        print("🔧 TESTANDO PAGINAÇÃO CORRIGIDA DO SENADO...")

        # Testa as primeiras 3 páginas
        for pagina in range(1, 4):
            try:
                if pagina == 1:
                    url = "https://www12.senado.leg.br/noticias/ultimas"
                else:
                    url = f"https://www12.senado.leg.br/noticias/ultimas/{pagina}"

                print(f"\n📄 Testando página {pagina}: {url}")
                response = requests.get(url, headers=self.headers, timeout=30)

                if response.status_code == 200:
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Busca notícias
                    links = soup.find_all('a', href=lambda x: x and '/noticias/' in x)
                    noticias_encontradas = 0

                    for link in links[:10]:  # Testa apenas os primeiros 10
                        titulo = link.get_text(strip=True)
                        if len(titulo) > 10:  # Só conta títulos reais
                            noticias_encontradas += 1

                    print(f"✅ Status: {response.status_code}")
                    print(f"📰 Notícias válidas encontradas: {noticias_encontradas}")

                    if noticias_encontradas > 0:
                        print(f"🎯 Página {pagina} funcionando corretamente!")
                    else:
                        print(f"⚠️ Página {pagina} sem notícias válidas")

                else:
                    print(f"❌ Status: {response.status_code}")

            except Exception as e:
                print(f"❌ Erro na página {pagina}: {e}")

    def scrape_camara_noticias(self, max_pages=50):
        """
        Scraping das notícias da Câmara dos Deputados
        Coleta desde 01/07/2025 até as mais recentes
        """
        print("🏛️ Iniciando coleta da Câmara dos Deputados...")
        print(f"📅 Buscando notícias desde {self.data_limite.strftime('%d/%m/%Y')} até hoje...")
        url_base = "https://www.camara.leg.br/noticias/ultimas"
        noticias = []
        encontrou_data_limite = False

        for pagina in range(1, max_pages + 1):
            try:
                # Para páginas adicionais, usa o parâmetro de paginação
                url = f"{url_base}?pagina={pagina}" if pagina > 1 else url_base

                print(f"📄 Processando página {pagina}: {url}")
                response = requests.get(url, headers=self.headers, timeout=30)
                response.raise_for_status()

                soup = BeautifulSoup(response.content, 'html.parser')

                # Encontra o container de notícias
                container = soup.find('ul', class_='l-lista-noticias')
                if not container:
                    print(f"⚠️ Container não encontrado na página {pagina}")
                    break

                # Encontra todas as notícias
                articles = container.find_all('article', class_=lambda x: x and 'chamada' in x)

                if not articles:
                    print(f"⚠️ Nenhuma notícia encontrada na página {pagina}")
                    break

                print(f"📰 Encontradas {len(articles)} notícias na página {pagina}")

                noticias_validas_pagina = 0
                noticias_antigas_pagina = 0

                for article in articles:
                    try:
                        # Extrai título e link
                        title_link = article.find('a', class_=lambda x: x and 'titulo' in x)
                        if not title_link:
                            title_link = article.find('a')

                        if title_link:
                            titulo = title_link.get_text(strip=True)
                            link = urljoin(url_base, title_link.get('href', ''))
                        else:
                            continue

                        # Extrai data
                        data_element = article.find('span', class_=lambda x: x and 'data' in x)
                        if data_element:
                            data_texto = data_element.get_text(strip=True)
                            data_noticia = self.parse_date_camara(data_texto)
                        else:
                            continue

                        # Verifica se a data é válida (posterior a 01/07/2025)
                        if self.is_date_valid(data_noticia):
                            noticia = {
                                'fonte': 'Câmara dos Deputados',
                                'titulo': titulo,
                                'link': link,
                                'data_publicacao': data_noticia,
                                'data_texto': data_texto,
                                'data_coleta': datetime.now()
                            }

                            noticias.append(noticia)
                            noticias_validas_pagina += 1
                            print(f"✅ Coletada: {titulo[:50]}... ({data_texto})")

                        # Se encontrou notícia anterior a 01/07, marca flag
                        elif data_noticia and data_noticia < self.data_limite:
                            noticias_antigas_pagina += 1
                            print(f"⏰ Notícia anterior ao limite: {data_texto}")

                    except Exception as e:
                        print(f"❌ Erro ao processar notícia: {e}")
                        continue

                print(f"📊 Página {pagina}: {noticias_validas_pagina} válidas, {noticias_antigas_pagina} anteriores ao limite")

                # Se encontrou muitas notícias antigas (10+), provavelmente chegou no limite
                if noticias_antigas_pagina >= 10:
                    print(f"🎯 Atingiu o limite temporal na página {pagina}. Parando coleta da Câmara.")
                    encontrou_data_limite = True
                    break

                # Se não encontrou nenhuma notícia válida em várias páginas seguidas
                if noticias_validas_pagina == 0 and pagina > 10:
                    print(f"🎯 Nenhuma notícia válida encontrada. Parando coleta da Câmara.")
                    break

                time.sleep(2)  # Pausa entre requisições

            except Exception as e:
                print(f"❌ Erro na página {pagina}: {e}")
                break

        if encontrou_data_limite:
            print(f"✅ Câmara: Coleta completa desde 01/07/2025 - {len(noticias)} notícias coletadas")
        else:
            print(f"✅ Câmara: {len(noticias)} notícias coletadas (pode haver mais páginas)")

        return noticias

    def scrape_senado_noticias(self, max_pages=50):
        """
        Scraping das notícias do Senado Federal
        Coleta desde 01/07/2025 até as mais recentes
        """
        print("🏛️ Iniciando coleta do Senado Federal...")
        print(f"📅 Buscando notícias desde {self.data_limite.strftime('%d/%m/%Y')} até hoje...")
        url_base = "https://www12.senado.leg.br/noticias/ultimas"
        noticias = []
        encontrou_data_limite = False

        for pagina in range(1, max_pages + 1):
            try:
                # URL com paginação correta baseada na imagem do DevTools
                if pagina == 1:
                    url = url_base
                else:
                    # Formato correto confirmado na imagem: /ultimas/2, /ultimas/3, etc.
                    url = f"{url_base}/{pagina}"

                print(f"📄 Processando página {pagina}: {url}")
                response = requests.get(url, headers=self.headers, timeout=30)
                response.raise_for_status()

                soup = BeautifulSoup(response.content, 'html.parser')

                # Múltiplas tentativas para encontrar o container
                container = None

                # Tentativa 1: Container principal que vimos nas imagens
                container = soup.find('div', class_='col-xs-12 col-md-9')

                # Tentativa 2: Lista de resultados
                if not container:
                    container = soup.find('ul', class_='list-unstyled lista-resultados')

                # Tentativa 3: Qualquer div que contenha notícias
                if not container:
                    container = soup.find('div', class_=lambda x: x and 'lista' in x) if soup.find('div', class_=lambda x: x and 'lista' in x) else soup

                if not container:
                    print(f"⚠️ Container não encontrado na página {pagina}")
                    print("🔍 Tentando busca alternativa...")
                    # Busca direta por links de notícias
                    articles = soup.find_all('a', href=lambda x: x and '/noticias/' in x)
                    if articles:
                        print(f"🎯 Encontrados {len(articles)} links alternativos")
                        container = soup  # Usa a página toda como container
                    else:
                        break

                # Estratégia robusta para encontrar notícias
                items = []

                # Tentativa 1: Elementos li (estrutura que esperávamos)
                items = container.find_all('li')

                # Tentativa 2: Se não achou li, busca por divs com classes de notícia
                if not items:
                    items = container.find_all('div', class_=lambda x: x and any(palavra in x for palavra in ['noticia', 'item', 'story', 'article']))

                # Tentativa 3: Busca direta por links de notícias
                if not items:
                    links_noticias = container.find_all('a', href=lambda x: x and '/noticias/' in x)
                    items = [link.parent for link in links_noticias if link.parent]

                if not items:
                    print(f"⚠️ Nenhuma notícia encontrada na página {pagina}")
                    break

                print(f"📰 Encontradas {len(items)} notícias na página {pagina}")

                noticias_validas_pagina = 0
                noticias_antigas_pagina = 0

                for item in items:
                    try:
                        # Busca mais robusta por título e link
                        title_link = None

                        # Tentativa 1: Link direto no item
                        title_link = item.find('a', href=lambda x: x and '/noticias/' in x)

                        # Tentativa 2: Qualquer link no item
                        if not title_link:
                            title_link = item.find('a')

                        if not title_link:
                            continue

                        titulo = title_link.get_text(strip=True)
                        if len(titulo) < 10:  # Título muito curto, provavelmente não é uma notícia
                            continue

                        link = urljoin(url_base, title_link.get('href', ''))

                        # Busca mais robusta por data
                        texto_item = item.get_text()
                        data_match = re.search(r'(\d{2}/\d{2}/\d{4})\s*(\d{2}h\d{2}|\d{2}:\d{2})?', texto_item)

                        if data_match:
                            data_texto = data_match.group(0)
                            data_noticia = self.parse_date_senado(data_texto)
                        else:
                            # Se não achou data no formato esperado, tenta outros formatos
                            data_alt = re.search(r'(\d{2}/\d{2}/\d{4})', texto_item)
                            if data_alt:
                                data_texto = data_alt.group(0)
                                data_noticia = self.parse_date_senado(data_texto)
                            else:
                                continue

                        # Verifica se a data é válida (posterior a 01/07/2025)
                        if self.is_date_valid(data_noticia):
                            noticia = {
                                'fonte': 'Senado Federal',
                                'titulo': titulo,
                                'link': link,
                                'data_publicacao': data_noticia,
                                'data_texto': data_texto,
                                'data_coleta': datetime.now()
                            }

                            noticias.append(noticia)
                            noticias_validas_pagina += 1
                            print(f"✅ Coletada: {titulo[:50]}... ({data_texto})")

                        # Se encontrou notícia anterior a 01/07, marca flag
                        elif data_noticia and data_noticia < self.data_limite:
                            noticias_antigas_pagina += 1
                            print(f"⏰ Notícia anterior ao limite: {data_texto}")

                    except Exception as e:
                        print(f"❌ Erro ao processar notícia: {e}")
                        continue

                print(f"📊 Página {pagina}: {noticias_validas_pagina} válidas, {noticias_antigas_pagina} anteriores ao limite")

                # Se não encontrou nenhuma notícia válida e nem antigas, provavelmente acabaram as notícias
                if noticias_validas_pagina == 0 and noticias_antigas_pagina == 0:
                    print(f"🎯 Página vazia ou sem conteúdo relevante na página {pagina}. Parando coleta do Senado.")
                    break

                # Se encontrou muitas notícias antigas (10+), provavelmente chegou no limite
                if noticias_antigas_pagina >= 10:
                    print(f"🎯 Atingiu o limite temporal na página {pagina}. Parando coleta do Senado.")
                    encontrou_data_limite = True
                    break

                time.sleep(2)  # Pausa entre requisições

            except Exception as e:
                print(f"❌ Erro na página {pagina}: {e}")
                break

        if encontrou_data_limite:
            print(f"✅ Senado: Coleta completa desde 01/07/2025 - {len(noticias)} notícias coletadas")
        else:
            print(f"✅ Senado: {len(noticias)} notícias coletadas (pode haver mais páginas)")

        return noticias

    def debug_senado_structure(self):
        """
        Função de debug para analisar a estrutura da página do Senado
        """
        print("🔍 MODO DEBUG - Analisando estrutura do Senado...")
        url = "https://www12.senado.leg.br/noticias/ultimas"

        try:
            response = requests.get(url, headers=self.headers, timeout=30)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, 'html.parser')

            print(f"✅ Página carregada com sucesso")
            print(f"📄 Título da página: {soup.title.get_text() if soup.title else 'N/A'}")

            # Procura por diferentes containers possíveis
            containers = [
                soup.find('ul', class_='list-unstyled lista-resultados'),
                soup.find('div', class_='col-xs-12 col-md-9'),
                soup.find('div', id='conteudoPrincipal'),
                soup.find('main'),
                soup.find('div', class_=lambda x: x and 'noticias' in x),
            ]

            print("\n🔍 Containers encontrados:")
            for i, container in enumerate(containers):
                if container:
                    print(f"  ✅ Container {i+1}: {container.name} - {container.get('class', [])} - {container.get('id', 'N/A')}")
                else:
                    print(f"  ❌ Container {i+1}: Não encontrado")

            # Busca por todos os links de notícias
            links_noticias = soup.find_all('a', href=lambda x: x and '/noticias/' in x)
            print(f"\n📰 Total de links de notícias encontrados: {len(links_noticias)}")

            if links_noticias:
                print("📋 Primeiros 5 links encontrados:")
                for i, link in enumerate(links_noticias[:5]):
                    titulo = link.get_text(strip=True)
                    href = link.get('href', '')
                    print(f"  {i+1}. {titulo[:60]}... -> {href}")

            # Busca por datas
            texto_pagina = soup.get_text()
            datas_encontradas = re.findall(r'\d{2}/\d{2}/\d{4}', texto_pagina)
            print(f"\n📅 Padrões de data encontrados: {len(set(datas_encontradas))} únicos")
            print(f"    Exemplos: {list(set(datas_encontradas))[:5]}")

            return soup

        except Exception as e:
            print(f"❌ Erro no debug: {e}")
            return None

    def executar_coleta_completa(self, max_pages_camara=50, max_pages_senado=50):
        """
        Executa a coleta completa de ambas as fontes
        Coleta desde 01/07/2025 até as notícias mais recentes
        """
        print("🚀 INICIANDO COLETA HISTÓRICA DE NOTÍCIAS LEGISLATIVAS")
        print("📅 Período: 01/07/2025 até hoje")
        print("=" * 60)

        # Coleta da Câmara
        noticias_camara = self.scrape_camara_noticias(max_pages_camara)

        print("\n" + "=" * 60)

        # Coleta do Senado
        noticias_senado = self.scrape_senado_noticias(max_pages_senado)

        # Consolida resultados
        todas_noticias = noticias_camara + noticias_senado
        self.noticias_coletadas = todas_noticias

        print("\n" + "=" * 60)
        print("📊 RESUMO DA COLETA HISTÓRICA:")
        print(f"🏛️ Câmara dos Deputados: {len(noticias_camara)} notícias")
        print(f"🏛️ Senado Federal: {len(noticias_senado)} notícias")
        print(f"📈 Total coletado: {len(todas_noticias)} notícias")

        if todas_noticias:
            # Calcula estatísticas de período
            datas = [n['data_publicacao'] for n in todas_noticias if n['data_publicacao']]
            if datas:
                data_mais_antiga = min(datas)
                data_mais_recente = max(datas)
                print(f"📅 Período coberto: {data_mais_antiga.strftime('%d/%m/%Y')} a {data_mais_recente.strftime('%d/%m/%Y')}")

        return todas_noticias

    def gerar_dataframe(self):
        """
        Converte as notícias coletadas em DataFrame pandas
        """
        if not self.noticias_coletadas:
            print("⚠️ Nenhuma notícia coletada ainda. Execute primeiro a coleta.")
            return None

        df = pd.DataFrame(self.noticias_coletadas)

        # Ordena por data de publicação (mais recentes primeiro)
        df = df.sort_values('data_publicacao', ascending=False)
        df = df.reset_index(drop=True)

        return df

    def salvar_csv(self, nome_arquivo=None):
        """
        Salva as notícias em arquivo CSV
        """
        df = self.gerar_dataframe()
        if df is None:
            return None

        if nome_arquivo is None:
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            nome_arquivo = f'clipping_legislativo_{timestamp}.csv'

        df.to_csv(nome_arquivo, index=False, encoding='utf-8')
        print(f"💾 Arquivo salvo: {nome_arquivo}")
        return nome_arquivo

# =============================================================================
# EXEMPLO DE USO
# =============================================================================

if __name__ == "__main__":
    # Inicializa o sistema
    clipping = NewsClippingSystem()

    # TESTE RÁPIDO: Descomente para testar a paginação do Senado antes da coleta completa:
    # clipping.testar_paginacao_senado_corrigida()

    # Executa a coleta (ajuste max_pages conforme necessário)
    # Para teste inicial, use números menores (ex: 10, 10)
    # Para coleta completa até 01/07, use números maiores (ex: 50, 50)
    noticias = clipping.executar_coleta_completa(max_pages_camara=50, max_pages_senado=50)

    # Gera DataFrame para análise
    df = clipping.gerar_dataframe()

    if df is not None and len(df) > 0:
        print("\n📋 PREVIEW DOS DADOS:")
        print(df[['fonte', 'titulo', 'data_publicacao']].head(10))

        print(f"\n📊 ESTATÍSTICAS:")
        print(f"Período: {df['data_publicacao'].min()} a {df['data_publicacao'].max()}")
        print(f"Distribuição por fonte:")
        print(df['fonte'].value_counts())

        # Salva em CSV
        arquivo = clipping.salvar_csv()

        print(f"\n✅ Coleta finalizada com sucesso!")
        print(f"📁 Dados disponíveis no DataFrame 'df' e no arquivo '{arquivo}'")

        # Se o Senado não coletou nada, sugere debug
        if 'Senado Federal' not in df['fonte'].values:
            print("\n⚠️ ATENÇÃO: Nenhuma notícia do Senado foi coletada.")
            print("💡 Para testar, execute: clipping.testar_paginacao_senado_corrigida()")

        # Se não chegou até 01/07, sugere aumentar páginas
        if df is not None and len(df) > 0:
            data_mais_antiga = df['data_publicacao'].min()
            if data_mais_antiga > datetime(2025, 7, 1):
                print(f"\n📅 ATENÇÃO: Não chegou até 01/07/2025 (parou em {data_mais_antiga.strftime('%d/%m/%Y')})")
                print("💡 Dica: Aumente o número de páginas para coletar mais histórico.")
                print("💡 Exemplo: clipping.executar_coleta_completa(max_pages_camara=60, max_pages_senado=60)")
    else:
        print("⚠️ Nenhuma notícia foi coletada no período especificado.")
# Out:
# 🚀 INICIANDO COLETA HISTÓRICA DE NOTÍCIAS LEGISLATIVAS
# 📅 Período: 01/07/2025 até hoje
# ============================================================
# 🏛️ Iniciando coleta da Câmara dos Deputados...
# 📅 Buscando notícias desde 01/07/2025 até hoje...
# 📄 Processando página 1: https://www.camara.leg.br/noticias/ultimas
# 📰 Encontradas 10 notícias na página 1
# ✅ Coletada: Comissão aprova proposta de estímulo fiscal para p... (18/07/2025 18:28)
# ✅ Coletada: Comissão aprova projeto que obriga serviços de saú... (18/07/2025 18:09)
# ✅ Coletada: Projeto cria novo marco legal do transporte indivi... (18/07/2025 17:31)
# ✅ Coletada: Comissão aprova projeto que prevê uso de algoritmo... (18/07/2025 16:57)
# ✅ Coletada: Hugo Motta e Davi Alcolumbre confirmam recesso par... (18/07/2025 16:29)
# ✅ Coletada: Oposição acusa Moraes de "abuso de autoridade"; lí... (18/07/2025 16:09)
# ✅ Coletada: Câmara cria comissão para analisar regulamentação ... (18/07/2025 16:08)
# ✅ Coletada: Projeto propõe medidas contra assédio e violência ... (18/07/2025 15:23)
# ✅ Coletada: Proposta amplia limite de receita bruta para trans... (18/07/2025 15:17)
# ✅ Coletada: Projeto determina a instalação de câmeras de segur... (18/07/2025 14:38)
# 📊 Página 1: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 2: https://www.camara.leg.br/noticias/ultimas?pagina=2
# 📰 Encontradas 10 notícias na página 2
# ✅ Coletada: Lei cria rota turística em litoral de Santa Catari... (18/07/2025 14:02)
# ✅ Coletada: Lei cria a Rota Turística Imperial Caminho dos Prí... (18/07/2025 13:40)
# ✅ Coletada: Taxação dos EUA continua dividindo opiniões na Câm... (18/07/2025 13:39)
# ✅ Coletada: Comissão aprova ampliação dos recursos do Fundo Na... (18/07/2025 13:34)
# ✅ Coletada: Comissão aprova prisão preventiva de familiares qu... (18/07/2025 13:24)
# ✅ Coletada: Comissão aprova identificação de quem tem doença r... (18/07/2025 11:33)
# ✅ Coletada: Comissão aprova garantia de suplementação alimenta... (18/07/2025 11:29)
# ✅ Coletada: Comissão aprova medida que reforça o direito de au... (18/07/2025 11:23)
# ✅ Coletada: Comissão aprova programas de visitação de crianças... (18/07/2025 11:17)
# ✅ Coletada: Comissão aprova projeto que obriga SUS a realizar ... (18/07/2025 10:14)
# 📊 Página 2: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 3: https://www.camara.leg.br/noticias/ultimas?pagina=3
# 📰 Encontradas 10 notícias na página 3
# ✅ Coletada: Comissão aprova classificação da espinha bífida co... (18/07/2025 09:00)
# ✅ Coletada: Comissão aprova centros psicopedagógicos para cria... (17/07/2025 20:01)
# ✅ Coletada: Para especialistas, prevenção de quedas entre idos... (17/07/2025 19:30)
# ✅ Coletada: Comissão aprova projeto que proíbe qualquer caso d... (17/07/2025 19:17)
# ✅ Coletada: Comissão aprova oferta de educação especial ao alu... (17/07/2025 19:02)
# ✅ Coletada: Comissão aprova regra para facilitar identificação... (17/07/2025 18:51)
# ✅ Coletada: Comissão aprova exigência de informações sobre cal... (17/07/2025 18:39)
# ✅ Coletada: Comissão aprova criação de programa para ajudar pe... (17/07/2025 17:40)
# ✅ Coletada: Comissão aprova projeto que suspende regulamentaçã... (17/07/2025 16:32)
# ✅ Coletada: Especialistas em câncer de cabeça e pescoço ressal... (17/07/2025 16:26)
# 📊 Página 3: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 4: https://www.camara.leg.br/noticias/ultimas?pagina=4
# 📰 Encontradas 10 notícias na página 4
# ✅ Coletada: Comissão aprova proposta de áreas exclusivas para ... (17/07/2025 16:19)
# ✅ Coletada: Comissão aprova projeto que obriga plataformas dig... (17/07/2025 16:15)
# ✅ Coletada: Comissão aprova ampliação da cota para pessoas com... (17/07/2025 15:31)
# ✅ Coletada: Comissão aprova projeto que destina 0,1% da arreca... (17/07/2025 14:53)
# ✅ Coletada: Comissão aprova selo de boas práticas de acessibil... (17/07/2025 13:50)
# ✅ Coletada: Projeto abre crédito suplementar de R$ 2,15 bilhõe... (17/07/2025 13:23)
# ✅ Coletada: Lula veta projeto que aumenta de 513 para 531 o nú... (17/07/2025 13:01)
# ✅ Coletada: Hugo Motta cria programa Câmara pelo Brasil, para ... (17/07/2025 12:49)
# ✅ Coletada: Medida provisória abre crédito de R$ 3,3 bilhões p... (17/07/2025 12:31)
# ✅ Coletada: Comissão aprova proibição de abastecimento de veíc... (17/07/2025 12:22)
# 📊 Página 4: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 5: https://www.camara.leg.br/noticias/ultimas?pagina=5
# 📰 Encontradas 10 notícias na página 5
# ✅ Coletada: Parlamentares e representantes do setor esportivo ... (17/07/2025 11:45)
# ✅ Coletada: Projeto inclui matéria sobre autismo na formação d... (17/07/2025 11:26)
# ✅ Coletada: Comissão aprova projeto que prevê medidas para seg... (17/07/2025 11:13)
# ✅ Coletada: Comissão rejeita projeto que proíbe marcação de an... (17/07/2025 10:56)
# ✅ Coletada: Comissão aprova projeto que prevê compensação ao c... (17/07/2025 09:51)
# ✅ Coletada: Saiba mais sobre o projeto que altera o licenciame... (17/07/2025 06:00)
# ✅ Coletada: Deputados manifestam-se a favor e contra o projeto... (17/07/2025 04:35)
# ✅ Coletada: Câmara aprova projeto que altera regras de licenci... (17/07/2025 03:55)
# ✅ Coletada: Deputados analisam projeto que altera regras de li... (17/07/2025 00:19)
# ✅ Coletada: Câmara aprova projeto que facilita acesso do agric... (16/07/2025 23:56)
# 📊 Página 5: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 6: https://www.camara.leg.br/noticias/ultimas?pagina=6
# 📰 Encontradas 10 notícias na página 6
# ✅ Coletada: Câmara aprova projeto que atribui à Caixa assumir ... (16/07/2025 23:36)
# ✅ Coletada: Câmara aprova uso de fundo social para agricultore... (16/07/2025 23:03)
# ✅ Coletada: Deputados analisam uso de fundo social para agricu... (16/07/2025 20:59)
# ✅ Coletada: Câmara aprova projeto que cria fundo de financiame... (16/07/2025 20:53)
# ✅ Coletada: Deputados e especialistas afirmam que criminalizaç... (16/07/2025 20:10)
# ✅ Coletada: Deputados comentam decisão de Moraes de validar ma... (16/07/2025 19:58)
# ✅ Coletada: Deputados analisam projeto que cria fundo de finan... (16/07/2025 19:42)
# ✅ Coletada: Comissão aprova equiparação da distonia a deficiên... (16/07/2025 19:37)
# ✅ Coletada: Câmara decide que projeto sobre crimes de trabalho... (16/07/2025 19:15)
# ✅ Coletada: Comissão aprova projeto que garante a aluno autist... (16/07/2025 18:58)
# 📊 Página 6: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 7: https://www.camara.leg.br/noticias/ultimas?pagina=7
# 📰 Encontradas 10 notícias na página 7
# ✅ Coletada: Comissão aprova auxílio financeiro para cuidador f... (16/07/2025 18:51)
# ✅ Coletada: Deputados analisam pedido de votação em Plenário d... (16/07/2025 18:42)
# ✅ Coletada: Comissão aprova obrigação do SUS oferecer cirurgia... (16/07/2025 18:40)
# ✅ Coletada: COP30 poderá ter espaço formal para participação d... (16/07/2025 18:39)
# ✅ Coletada: Câmara aprova regime de urgência para cinco projet... (16/07/2025 18:30)
# ✅ Coletada: Motta cria comissão especial para analisar PEC da ... (16/07/2025 18:08)
# ✅ Coletada: Deputados analisam pedidos de urgência para projet... (16/07/2025 17:27)
# ✅ Coletada: Comissão aprova obrigatoriedade de autorização jud... (16/07/2025 17:21)
# ✅ Coletada: Projeto torna obrigatória autorização judicial pré... (16/07/2025 16:43)
# ✅ Coletada: Comissão aprova proibição de custódia de presos em... (16/07/2025 16:40)
# 📊 Página 7: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 8: https://www.camara.leg.br/noticias/ultimas?pagina=8
# 📰 Encontradas 10 notícias na página 8
# ✅ Coletada: Comissão aprova diagnóstico e tratamento de trombo... (16/07/2025 16:33)
# ✅ Coletada: Comissão aprova garantia de atendimento prioritári... (16/07/2025 15:10)
# ✅ Coletada: Comissão aprova gratuidade do georreferenciamento ... (16/07/2025 15:01)
# ✅ Coletada: Comissão aprova projeto que garante continuidade d... (16/07/2025 14:58)
# ✅ Coletada: Comissão aprova campanhas educativas permanentes d... (16/07/2025 14:55)
# ✅ Coletada: Comissão aprova publicação a cada dois anos de rel... (16/07/2025 14:50)
# ✅ Coletada: Comissão aprova oferta de curso de Libras em unive... (16/07/2025 14:46)
# ✅ Coletada: Comissão da Câmara aprova projeto que isenta de Im... (16/07/2025 14:39)
# ✅ Coletada: Profissionais pedem atualização das normas em tera... (16/07/2025 12:57)
# ✅ Coletada: Comissão aprova prioridade para gestantes e lactan... (16/07/2025 12:54)
# 📊 Página 8: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 9: https://www.camara.leg.br/noticias/ultimas?pagina=9
# 📰 Encontradas 10 notícias na página 9
# ✅ Coletada: Tarifas dos EUA: Motta diz que o Congresso está pr... (16/07/2025 12:53)
# ✅ Coletada: Comissão aprova projeto que proíbe escolas de prom... (16/07/2025 11:39)
# ✅ Coletada: Projeto prevê regras para proteção de crianças e a... (16/07/2025 11:17)
# ✅ Coletada: Comissão debate regras para contratação temporária... (16/07/2025 11:12)
# ✅ Coletada: Motta é agraciado com a Medalha Mérito Santos-Dumo... (16/07/2025 11:11)
# ✅ Coletada: Câmara cancela debate sobre securitização de dívid... (16/07/2025 11:09)
# ✅ Coletada: Para Motta, atual momento é de unidade nacional pa... (16/07/2025 10:40)
# ✅ Coletada: Cancelado debate sobre inclusão de pessoas autista... (16/07/2025 09:35)
# ✅ Coletada: Câmara dos Deputados pode votar hoje regras para r... (16/07/2025 09:19)
# ✅ Coletada: Comissões de Esporte da Câmara e do Senado debatem... (16/07/2025 09:05)
# 📊 Página 9: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 10: https://www.camara.leg.br/noticias/ultimas?pagina=10
# 📰 Encontradas 10 notícias na página 10
# ✅ Coletada: Câmara cancela debate sobre mecanismos de fortalec... (16/07/2025 08:29)
# ✅ Coletada: Comissão do Imposto de Renda debate parecer do rel... (16/07/2025 08:24)
# ✅ Coletada: Cancelado debate sobre medidas de proteção aos ido... (16/07/2025 08:20)
# ✅ Coletada: Câmara dos Deputados discute preparativos para a C... (16/07/2025 08:18)
# ✅ Coletada: Câmara aprova projeto que aperfeiçoa sistema de al... (16/07/2025 00:50)
# ✅ Coletada: Motta espera votação rápida no Senado da proposta ... (16/07/2025 00:32)
# ✅ Coletada: Câmara aprova novas regras para benefício fiscal a... (16/07/2025 00:24)
# ✅ Coletada: Câmara aprova regime de urgência para três projeto... (16/07/2025 00:21)
# ✅ Coletada: Câmara aprova em 2º turno PEC que altera regras pa... (16/07/2025 00:09)
# ✅ Coletada: Relator da reforma administrativa adianta pontos d... (15/07/2025 22:56)
# 📊 Página 10: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 11: https://www.camara.leg.br/noticias/ultimas?pagina=11
# 📰 Encontradas 10 notícias na página 11
# ✅ Coletada: Aprovada em 1º turno PEC que altera regras para pa... (15/07/2025 22:29)
# ✅ Coletada: Motta cancela reuniões das comissões permanentes p... (15/07/2025 21:08)
# ✅ Coletada: Comissão aprova assistência à saúde ocular para cr... (15/07/2025 21:03)
# ✅ Coletada: Comissão aprova auxílio financeiro e psicológico a... (15/07/2025 21:02)
# ✅ Coletada: Corregedoria notifica deputados sobre processo de ... (15/07/2025 20:44)
# ✅ Coletada: Comissão de Constituição e Justiça aprova admissib... (15/07/2025 19:36)
# ✅ Coletada: Comissão aprova extensão das regras da lei dos age... (15/07/2025 19:31)
# ✅ Coletada: Câmara analisa PEC que altera regras para pagament... (15/07/2025 19:23)
# ✅ Coletada: Comissão especial aprova parecer sobre proposta qu... (15/07/2025 18:26)
# ✅ Coletada: Governo e Congresso não chegam a acordo sobre aume... (15/07/2025 18:12)
# 📊 Página 11: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 12: https://www.camara.leg.br/noticias/ultimas?pagina=12
# 📰 Encontradas 10 notícias na página 12
# ✅ Coletada: Frentes parlamentares lançam manifesto pelo adiame... (15/07/2025 18:00)
# ✅ Coletada: Comissão Mista de Orçamento aprova relatório preli... (15/07/2025 17:49)
# ✅ Coletada: Comissão aprova cobertura obrigatória de tratament... (15/07/2025 17:28)
# ✅ Coletada: Câmara celebra 35 anos do Estatuto da Criança e do... (15/07/2025 16:43)
# ✅ Coletada: Lei que amplia destinação do Fundo Social do Pré-S... (15/07/2025 16:10)
# ✅ Coletada: Deputado André Janones está suspenso do mandato po... (15/07/2025 16:09)
# ✅ Coletada: Comissão aprova proposta que facilita acesso de pe... (15/07/2025 15:43)
# ✅ Coletada: Cancelado debate sobre o impacto de tarifas dos EU... (15/07/2025 15:24)
# ✅ Coletada: Medida provisória extingue cobrança por vistoria d... (15/07/2025 14:53)
# ✅ Coletada: Câmara lança concurso de vídeo "Pelo Fim da Violên... (15/07/2025 14:00)
# 📊 Página 12: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 13: https://www.camara.leg.br/noticias/ultimas?pagina=13
# 📰 Encontradas 10 notícias na página 13
# ✅ Coletada: Comissão aprova novo critério de renda para a soli... (15/07/2025 13:43)
# ✅ Coletada: Projeto que cria Sistema Nacional de Educação divi... (15/07/2025 13:38)
# ✅ Coletada: Medida provisória tenta limitar impacto de subsídi... (15/07/2025 13:23)
# ✅ Coletada: Comissão aprova preferência para turismo na distri... (15/07/2025 13:11)
# ✅ Coletada: Comissão aprova projeto que obriga banco a informa... (15/07/2025 11:51)
# ✅ Coletada: Comissão aprova criação de documento para identifi... (15/07/2025 11:20)
# ✅ Coletada: Comissão aprova projeto que inclui a compra de tub... (15/07/2025 10:49)
# ✅ Coletada: Seminário na Câmara discute como prevenir quedas d... (15/07/2025 10:47)
# ✅ Coletada: Seminário na Câmara aponta demora no tratamento do... (15/07/2025 10:43)
# ✅ Coletada: Comissão aprova instalação obrigatória de brinqued... (15/07/2025 10:32)
# 📊 Página 13: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 14: https://www.camara.leg.br/noticias/ultimas?pagina=14
# 📰 Encontradas 10 notícias na página 14
# ✅ Coletada: Comissão aprova programa de proteção a grupos vuln... (15/07/2025 10:18)
# ✅ Coletada: Deputados podem votar hoje o projeto que muda as r... (15/07/2025 09:15)
# ✅ Coletada: Comissão debate retomada das atividades no Rio Gra... (15/07/2025 08:47)
# ✅ Coletada: Comissão debate sustentabilidade na produção e na ... (15/07/2025 08:45)
# ✅ Coletada: Comissão debate implementação da lei que instituiu... (15/07/2025 08:38)
# ✅ Coletada: Comissão discute transição demográfica e envelheci... (15/07/2025 08:35)
# ✅ Coletada: Conselho de Ética analisa processo contra deputado... (15/07/2025 08:34)
# ✅ Coletada: Comissão da Câmara debate concessão de aposentador... (15/07/2025 08:31)
# ✅ Coletada: Parecer com novas regras para pagamento de precató... (15/07/2025 08:30)
# ✅ Coletada: Comissão debate conscientização, diagnóstico e tra... (15/07/2025 08:30)
# 📊 Página 14: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 15: https://www.camara.leg.br/noticias/ultimas?pagina=15
# 📰 Encontradas 10 notícias na página 15
# ✅ Coletada: Comissão de Saúde debate atualização de normas par... (15/07/2025 08:27)
# ✅ Coletada: Câmara aprova ampliação de atividades que poderão ... (14/07/2025 23:15)
# ✅ Coletada: Câmara aprova novas regras para liberação de recur... (14/07/2025 22:51)
# ✅ Coletada: Câmara aprova criação do cadastro nacional de pess... (14/07/2025 22:23)
# ✅ Coletada: Câmara aprova projeto que prevê em lei a atuação d... (14/07/2025 22:03)
# ✅ Coletada: Hugo Motta diz que aprovação de lei de incentivo d... (14/07/2025 21:41)
# ✅ Coletada: Câmara aprova projeto que torna permanente a Lei d... (14/07/2025 21:34)
# ✅ Coletada: Comissão aprova criação do selo Instituição Amiga ... (14/07/2025 20:40)
# ✅ Coletada: Câmara aprova urgência para seis projetos de lei... (14/07/2025 20:22)
# ✅ Coletada: Deputados analisam projeto que torna permanente a ... (14/07/2025 20:16)
# 📊 Página 15: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 16: https://www.camara.leg.br/noticias/ultimas?pagina=16
# 📰 Encontradas 10 notícias na página 16
# ✅ Coletada: Comissão aprova adoção de novo ícone para sinaliza... (14/07/2025 19:39)
# ✅ Coletada: Projeto cria centros psicopedagógicos para criança... (14/07/2025 19:34)
# ✅ Coletada: Comissão aprova meia-entrada para pessoa com defic... (14/07/2025 18:42)
# ✅ Coletada: Projeto abre crédito suplementar de R$ 3,3 milhões... (14/07/2025 18:36)
# ✅ Coletada: Comissão aprova proposta que isenta de tributo a i... (14/07/2025 17:39)
# ✅ Coletada: Projeto abre crédito suplementar de R$ 14,2 milhõe... (14/07/2025 17:34)
# ✅ Coletada: Comissão aprova busca ativa para identificar estud... (14/07/2025 16:37)
# ✅ Coletada: Comissão aprova assistência integral no SUS à pess... (14/07/2025 16:35)
# ✅ Coletada: Comissão aprova proibição de uso de recursos do Fu... (14/07/2025 16:32)
# ✅ Coletada: Comissão aprova política nacional para distrofias ... (14/07/2025 15:58)
# 📊 Página 16: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 17: https://www.camara.leg.br/noticias/ultimas?pagina=17
# 📰 Encontradas 10 notícias na página 17
# ✅ Coletada: Comissão aprova regra para remoção nas redes de co... (14/07/2025 15:53)
# ✅ Coletada: Comissão aprova novas regras para proteção de cons... (14/07/2025 15:48)
# ✅ Coletada: CCJ aprova notificação compulsória de acidentes co... (14/07/2025 14:59)
# ✅ Coletada: Comissão aprova alerta em bulas e embalagens sobre... (14/07/2025 14:55)
# ✅ Coletada: Cancelada audiência com a ministra dos Direitos Hu... (14/07/2025 14:53)
# ✅ Coletada: Câmara e Senado pedem que STF reconheça decisão qu... (14/07/2025 14:52)
# ✅ Coletada: Cancelado debate sobre governança da inteligência ... (14/07/2025 14:47)
# ✅ Coletada: Cancelado debate sobre desafios do acesso à quimio... (14/07/2025 13:42)
# ✅ Coletada: Comissão aprova inclusão de mototaxista e motoboy ... (14/07/2025 13:32)
# ✅ Coletada: Comissão aprova criação de fundo para fomentar emp... (14/07/2025 12:55)
# 📊 Página 17: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 18: https://www.camara.leg.br/noticias/ultimas?pagina=18
# 📰 Encontradas 10 notícias na página 18
# ✅ Coletada: Comissão de Constituição e Justiça aprova tratamen... (14/07/2025 12:50)
# ✅ Coletada: Comissão aprova penas maiores para crimes contra a... (14/07/2025 11:33)
# ✅ Coletada: Comissão aprova projeto que torna facultativa a ad... (14/07/2025 11:31)
# ✅ Coletada: Comissão aprova isenção de impostos para equipamen... (14/07/2025 10:23)
# ✅ Coletada: Câmara pode votar a partir desta segunda-feira nov... (14/07/2025 08:27)
# ✅ Coletada: Comissão debate condições de trabalho dos profissi... (14/07/2025 08:20)
# ✅ Coletada: Comissão aprova projeto da Lei Juliana Marins sobr... (11/07/2025 18:01)
# ✅ Coletada: Comissão aprova regra para sucessão em sociedade l... (11/07/2025 17:55)
# ✅ Coletada: Motta reafirma disposição da Câmara para agir em d... (11/07/2025 17:38)
# ✅ Coletada: Comissão aprova desconto em voo para acompanhante ... (11/07/2025 15:41)
# 📊 Página 18: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 19: https://www.camara.leg.br/noticias/ultimas?pagina=19
# 📰 Encontradas 10 notícias na página 19
# ✅ Coletada: Comissão aprova prioridade para trabalhador tirar ... (11/07/2025 14:56)
# ✅ Coletada: Comissão aprova ampliação da fatia do FPM para mun... (11/07/2025 13:04)
# ✅ Coletada: Comissão aprova regras específicas para a educação... (11/07/2025 11:49)
# ✅ Coletada: Comissão aprova criação de programa de incentivo à... (11/07/2025 11:44)
# ✅ Coletada: Comissão aprova medidas para incentivar o diagnóst... (11/07/2025 10:58)
# ✅ Coletada: Comissão aprova projeto que prioriza honorários ad... (11/07/2025 10:50)
# ✅ Coletada: CCJ aprova ampliação da licença-maternidade em cas... (11/07/2025 10:32)
# ✅ Coletada: Projeto isenta de impostos equipamentos de acessib... (11/07/2025 09:58)
# ✅ Coletada: Comissão aprova criação de sistema de combate à pe... (11/07/2025 08:49)
# ✅ Coletada: Debatedores alertam para riscos de perda de autono... (10/07/2025 19:33)
# 📊 Página 19: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 20: https://www.camara.leg.br/noticias/ultimas?pagina=20
# 📰 Encontradas 10 notícias na página 20
# ✅ Coletada: Governo vê “dano irremediável” em projeto de novo ... (10/07/2025 19:27)
# ✅ Coletada: Relator eleva faixa que terá redução parcial do Im... (10/07/2025 18:59)
# ✅ Coletada: CCJ aprova projeto que cria programa para tratar m... (10/07/2025 18:44)
# ✅ Coletada: CCJ aprova uso de arbitragem por condomínio para s... (10/07/2025 18:32)
# ✅ Coletada: CCJ aprova assistência integral pelo SUS a criança... (10/07/2025 18:20)
# ✅ Coletada: Para Instituto Aço Brasil, aumento tarifário dos E... (10/07/2025 18:07)
# ✅ Coletada: CCJ aprova política para diagnosticar e tratar doe... (10/07/2025 17:56)
# ✅ Coletada: Assessoria jurídica de Carla Zambelli se compromet... (10/07/2025 17:38)
# ✅ Coletada: CCJ aprova campanha nacional de conscientização so... (10/07/2025 17:26)
# ✅ Coletada: Motta e Alcolumbre defendem diálogo, equilíbrio e ... (10/07/2025 17:12)
# 📊 Página 20: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 21: https://www.camara.leg.br/noticias/ultimas?pagina=21
# 📰 Encontradas 10 notícias na página 21
# ✅ Coletada: Comissão aprova dispensa de autorização de confede... (10/07/2025 16:48)
# ✅ Coletada: Policiais civis e militares de MG denunciam assédi... (10/07/2025 16:37)
# ✅ Coletada: CCJ aprova 17 projetos sobre cultura, homenagens e... (10/07/2025 15:50)
# ✅ Coletada: Licenciamento ambiental será votado na próxima sem... (10/07/2025 14:28)
# ✅ Coletada: Câmara aprova criação do Dia Nacional do Orgulho A... (10/07/2025 13:32)
# ✅ Coletada: Câmara aprova criação do grupo parlamentar Brasil-... (10/07/2025 13:09)
# ✅ Coletada: Comissão vota nesta tarde parecer sobre projeto qu... (10/07/2025 12:22)
# ✅ Coletada: Comissão aprova prazo de 90 dias para fornecimento... (10/07/2025 12:00)
# ✅ Coletada: Comissão aprova exigência de mobiliário adaptado n... (10/07/2025 11:52)
# ✅ Coletada: Câmara aprova reajuste dos soldos dos militares da... (10/07/2025 11:42)
# 📊 Página 21: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 22: https://www.camara.leg.br/noticias/ultimas?pagina=22
# 📰 Encontradas 10 notícias na página 22
# ✅ Coletada: Câmara dos Deputados analisa MP que reajusta soldo... (10/07/2025 11:30)
# ✅ Coletada: Plenário pode votar hoje renegociação de dívidas r... (10/07/2025 08:50)
# ✅ Coletada: Participação feminina no hip hop é tema de audiênc... (10/07/2025 07:41)
# ✅ Coletada: Racismo contra profissionais de enfermagem é tema ... (10/07/2025 07:39)
# ✅ Coletada: Comissão debate impactos das tarifas americanas so... (10/07/2025 07:36)
# ✅ Coletada: Audiência na Câmara debate projeto do Sistema Naci... (10/07/2025 07:33)
# ✅ Coletada: Comissão de Segurança debate combate a assédio e v... (10/07/2025 07:31)
# ✅ Coletada: Comissão debate impactos e riscos de mudanças no l... (10/07/2025 07:26)
# ✅ Coletada: Comissões debatem organização e participação socia... (10/07/2025 07:23)
# ✅ Coletada: Audiência discute proposta que proíbe cancelamento... (10/07/2025 07:22)
# 📊 Página 22: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 23: https://www.camara.leg.br/noticias/ultimas?pagina=23
# 📰 Encontradas 10 notícias na página 23
# ✅ Coletada: Relator antecipa pontos do anteprojeto de reforma ... (09/07/2025 22:16)
# ✅ Coletada: Câmara aprova projeto que proíbe uso de animais em... (09/07/2025 21:45)
# ✅ Coletada: Comissão aprova projeto que torna permanentes os i... (09/07/2025 21:04)
# ✅ Coletada: Deputados analisam projeto que proíbe uso de anima... (09/07/2025 20:44)
# ✅ Coletada: Presidente do Banco Central justifica taxa de juro... (09/07/2025 20:37)
# ✅ Coletada: Deputados criticam anúncio dos EUA de tarifa de 50... (09/07/2025 20:35)
# ✅ Coletada: Câmara aprova projeto que cria 40 cargos da políci... (09/07/2025 20:15)
# ✅ Coletada: Entra em vigor lei que aumenta as penas para aband... (09/07/2025 18:58)
# ✅ Coletada: Comissão aprova exigência de prova física adaptada... (09/07/2025 18:56)
# ✅ Coletada: Deputados retomam análise de projeto que cria carg... (09/07/2025 18:04)
# 📊 Página 23: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 24: https://www.camara.leg.br/noticias/ultimas?pagina=24
# 📰 Encontradas 10 notícias na página 24
# ✅ Coletada: Motta busca solução para as contas públicas sem au... (09/07/2025 18:03)
# ✅ Coletada: Diretor da Polícia Federal rebate acusações de uso... (09/07/2025 17:31)
# ✅ Coletada: Tebet afirma que custo das rotas de integração sul... (09/07/2025 16:59)
# ✅ Coletada: Comissão convoca ministro das Relações Exteriores ... (09/07/2025 16:42)
# ✅ Coletada: Lei cria o Dia do Conselheiro Comunitário de Segur... (09/07/2025 15:32)
# ✅ Coletada: No aniversário da independência da Bahia, sessão n... (09/07/2025 15:27)
# ✅ Coletada: Relator apresenta parecer favorável à PEC da Segur... (09/07/2025 14:43)
# ✅ Coletada: Comissão aprova diretrizes para assistência integr... (09/07/2025 14:31)
# ✅ Coletada: Ministro anuncia medida provisória para limitar en... (09/07/2025 14:06)
# ✅ Coletada: Ministro defende medida provisória que reestrutura... (09/07/2025 13:36)
# 📊 Página 24: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 25: https://www.camara.leg.br/noticias/ultimas?pagina=25
# 📰 Encontradas 10 notícias na página 25
# ✅ Coletada: Lei cria o Dia Nacional do Coco de Roda, da Cirand... (09/07/2025 12:39)
# ✅ Coletada: Câmara pode concluir hoje a votação do projeto que... (09/07/2025 11:35)
# ✅ Coletada: Entidades reclamam de demora e "burocracia" para a... (09/07/2025 11:28)
# ✅ Coletada: Seminário debate medidas para prevenir quedas acid... (09/07/2025 10:24)
# ✅ Coletada: Comissão especial vota parecer sobre nova Lei de I... (09/07/2025 10:23)
# ✅ Coletada: Grupo de trabalho debate hoje reforma administrati... (09/07/2025 09:13)
# ✅ Coletada: Seminário debate política de estímulo para minerai... (09/07/2025 08:45)
# ✅ Coletada: Comissão debate posição do Brasil na conferência s... (09/07/2025 08:33)
# ✅ Coletada: Comissões debatem projeto que cria a Zona Franca d... (09/07/2025 08:30)
# ✅ Coletada: Comissão ouve presidente do Banco Central nesta qu... (09/07/2025 08:27)
# 📊 Página 25: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 26: https://www.camara.leg.br/noticias/ultimas?pagina=26
# 📰 Encontradas 10 notícias na página 26
# ✅ Coletada: Comissões debatem rotas de integração sul-american... (09/07/2025 08:25)
# ✅ Coletada: Comissão promove audiência com o diretor-geral da ... (09/07/2025 08:22)
# ✅ Coletada: Comissão debate divisão da frequência entre as red... (09/07/2025 08:18)
# ✅ Coletada: Câmara instala nesta quarta-feira comissão especia... (09/07/2025 08:15)
# ✅ Coletada: Comissão debate impactos da medida provisória que ... (09/07/2025 08:08)
# ✅ Coletada: Aprovado texto-base de projeto que cria 40 cargos ... (09/07/2025 00:06)
# ✅ Coletada: Para especialistas, monitoramento de metas do novo... (08/07/2025 22:28)
# ✅ Coletada: Comissão mista aprova medida provisória com aument... (08/07/2025 22:17)
# ✅ Coletada: Congresso dará colaboração para trazer mais eficiê... (08/07/2025 21:28)
# ✅ Coletada: Oposição rebate campanha contra o Congresso nas re... (08/07/2025 21:12)
# 📊 Página 26: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 27: https://www.camara.leg.br/noticias/ultimas?pagina=27
# 📰 Encontradas 10 notícias na página 27
# ✅ Coletada: Deputado apresenta relatório preliminar da Lei de ... (08/07/2025 21:10)
# ✅ Coletada: Câmara aprova projeto que cria a Estratégia Nacion... (08/07/2025 20:52)
# ✅ Coletada: Comissão aprova atualização de normas sobre atendi... (08/07/2025 20:19)
# ✅ Coletada: Comissão aprova inclusão de alunos de universidade... (08/07/2025 20:07)
# ✅ Coletada: Projeto do governo institui o Dia da Consolidação ... (08/07/2025 20:02)
# ✅ Coletada: Comissão aprova oferta da linguagem tátil de cores... (08/07/2025 19:56)
# ✅ Coletada: Simone Tebet sugere revisão nas regras do Benefíci... (08/07/2025 19:39)
# ✅ Coletada: Conselho de Ética abre processo contra o deputado ... (08/07/2025 19:21)
# ✅ Coletada: Câmara aprova aumento de pena para furto de fios d... (08/07/2025 19:19)
# ✅ Coletada: Comissão aprova piso de R$ 4.650 para fisioterapeu... (08/07/2025 19:08)
# 📊 Página 27: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 28: https://www.camara.leg.br/noticias/ultimas?pagina=28
# 📰 Encontradas 10 notícias na página 28
# ✅ Coletada: Deputados analisam projeto que cria a Estratégia N... (08/07/2025 19:00)
# ✅ Coletada: Câmara aprova projeto que reforça medida protetiva... (08/07/2025 18:26)
# ✅ Coletada: Comissão aprova projeto que autoriza polícia a lib... (08/07/2025 18:12)
# ✅ Coletada: Comissão aprova previsão para vigilância socioassi... (08/07/2025 17:42)
# ✅ Coletada: Deputados analisam projeto que reforça medida prot... (08/07/2025 17:27)
# ✅ Coletada: Câmara rejeita recurso e confirma envio ao Senado ... (08/07/2025 17:24)
# ✅ Coletada: Comissão aprova formação específica para educadore... (08/07/2025 17:13)
# ✅ Coletada: Deputados vão decidir se projeto sobre agentes soc... (08/07/2025 17:09)
# ✅ Coletada: Debatedores apresentam sugestões para projeto sobr... (08/07/2025 17:09)
# ✅ Coletada: Câmara aprova regime de urgência para seis projeto... (08/07/2025 17:00)
# 📊 Página 28: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 29: https://www.camara.leg.br/noticias/ultimas?pagina=29
# 📰 Encontradas 10 notícias na página 29
# ✅ Coletada: Projeto obriga governo a reduzir benefícios tribut... (08/07/2025 16:26)
# ✅ Coletada: Estudantes pedem fim do teto do Fies e fiscalizaçã... (08/07/2025 15:13)
# ✅ Coletada: Governo e produtores rurais apoiam mudanças em des... (08/07/2025 15:08)
# ✅ Coletada: Comissão aprova proposta que amplia a possibilidad... (08/07/2025 15:03)
# ✅ Coletada: Nova lei aumenta penas para crimes cometidos em es... (08/07/2025 14:24)
# ✅ Coletada: Líderes decidem votar projeto que reduz benefícios... (08/07/2025 14:16)
# ✅ Coletada: Nova lei acaba com atenuante de idade para crimes ... (08/07/2025 14:14)
# ✅ Coletada: Projeto abre crédito no Orçamento para pagamento d... (08/07/2025 13:40)
# ✅ Coletada: Projeto abre crédito especial no Orçamento de 2025... (08/07/2025 13:26)
# ✅ Coletada: Projeto abre crédito no Orçamento para obras das j... (08/07/2025 13:21)
# 📊 Página 29: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 30: https://www.camara.leg.br/noticias/ultimas?pagina=30
# 📰 Encontradas 10 notícias na página 30
# ✅ Coletada: Comissão aprova sala reservada para criança e adol... (08/07/2025 12:16)
# ✅ Coletada: Comissão aprova regras para a circulação de carros... (08/07/2025 12:14)
# ✅ Coletada: Cancelado debate sobre impactos da operação padrão... (08/07/2025 10:30)
# ✅ Coletada: Projeto concede ao consumidor rural o direito de e... (08/07/2025 10:26)
# ✅ Coletada: Cancelado debate sobre a retomada das atividades n... (08/07/2025 09:52)
# ✅ Coletada: Comissão aprova marco legal para o turismo itinera... (08/07/2025 09:45)
# ✅ Coletada: Comissão debate programa "Pena Justa" com represen... (08/07/2025 09:30)
# ✅ Coletada: Comissão debate projeto que define regras para ava... (08/07/2025 09:25)
# ✅ Coletada: Comissão de Saúde discute combate ao câncer de cab... (08/07/2025 09:22)
# ✅ Coletada: Seminário na Câmara dos Deputados discute burocrac... (08/07/2025 09:18)
# 📊 Página 30: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 31: https://www.camara.leg.br/noticias/ultimas?pagina=31
# 📰 Encontradas 10 notícias na página 31
# ✅ Coletada: Comissão debate criminalização da cultura negra e ... (08/07/2025 09:15)
# ✅ Coletada: Conselho de Ética se reúne nesta terça para instau... (08/07/2025 09:14)
# ✅ Coletada: Comissão discute estrutura regulatória do mercado ... (08/07/2025 09:12)
# ✅ Coletada: Comissão de Orçamento debate projeto da LDO de 202... (08/07/2025 09:08)
# ✅ Coletada: Grupo de trabalho promove debate sobre carreiras e... (08/07/2025 09:05)
# ✅ Coletada: Comissão discute retomada da atividade nos aeropor... (08/07/2025 09:03)
# ✅ Coletada: Comissão vota parecer com novas regras para o paga... (08/07/2025 09:00)
# ✅ Coletada: Comissão do novo Plano Nacional de Educação promov... (08/07/2025 08:57)
# ✅ Coletada: Audiência discute impactos ambientais e sociais da... (08/07/2025 08:51)
# ✅ Coletada: Comissão promove novo debate sobre projeto que reg... (08/07/2025 08:44)
# 📊 Página 31: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 32: https://www.camara.leg.br/noticias/ultimas?pagina=32
# 📰 Encontradas 10 notícias na página 32
# ✅ Coletada: Comissão da Câmara discute inclusão de remédio par... (08/07/2025 08:42)
# ✅ Coletada: Comissão do Esporte avalia atividades do Comitê Br... (08/07/2025 08:38)
# ✅ Coletada: Audiência na Câmara discute concessão de aposentad... (08/07/2025 08:35)
# ✅ Coletada: Câmara discute regras para obtenção e uso de prova... (08/07/2025 08:33)
# ✅ Coletada: Audiência na Câmara discute os benefícios do vinho... (08/07/2025 08:26)
# ✅ Coletada: Comissão debate descontos de energia elétrica em a... (08/07/2025 08:23)
# ✅ Coletada: Comissão promove na Câmara a 3ª Virada Parlamentar... (08/07/2025 08:20)
# ✅ Coletada: Comissão debate altas coparticipações e crise no f... (08/07/2025 08:17)
# ✅ Coletada: Comissão debate plano de carreira dos servidores d... (08/07/2025 08:15)
# ✅ Coletada: Comissão aprova previsão de base de dados sobre pe... (07/07/2025 19:17)
# 📊 Página 32: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 33: https://www.camara.leg.br/noticias/ultimas?pagina=33
# 📰 Encontradas 10 notícias na página 33
# ✅ Coletada: Projeto dispensa laudo médico para que alunos tenh... (07/07/2025 18:03)
# ✅ Coletada: Comissão aprova mudanças no processo seletivo do S... (07/07/2025 18:03)
# ✅ Coletada: Comissão aprova projeto que prevê salas especiais ... (07/07/2025 17:44)
# ✅ Coletada: Comissão aprova projeto que cria vestibular especi... (07/07/2025 17:35)
# ✅ Coletada: Comissão aprova inclusão de adrenalina autoinjetáv... (07/07/2025 17:06)
# ✅ Coletada: Comissão aprova inclusão de condição crônica de sa... (07/07/2025 16:31)
# ✅ Coletada: Comissão aprova escolas comunitárias e confessiona... (07/07/2025 16:22)
# ✅ Coletada: Comissão aprova projeto que torna obrigatório ar-c... (07/07/2025 16:17)
# ✅ Coletada: Comissão aprova proposta para escola federal estar... (07/07/2025 16:14)
# ✅ Coletada: Comissão aprova proibição de fiança para acusado d... (07/07/2025 16:10)
# 📊 Página 33: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 34: https://www.camara.leg.br/noticias/ultimas?pagina=34
# 📰 Encontradas 10 notícias na página 34
# ✅ Coletada: Comissão aprova obrigatoriedade de intérprete de L... (07/07/2025 15:59)
# ✅ Coletada: Comissão aprova criação no SUS de política de aten... (07/07/2025 14:42)
# ✅ Coletada: Comissão debate concessão de serviços em unidades ... (07/07/2025 08:30)
# ✅ Coletada: Motta: narrativa de que o Congresso protege ricos ... (05/07/2025 10:40)
# ✅ Coletada: Comissão aprova aumento da pena para o crime de po... (04/07/2025 19:41)
# ✅ Coletada: Comissão aprova projeto para garantir contrato em ... (04/07/2025 18:40)
# ✅ Coletada: Comissão aprova responsabilidade de redes sociais ... (04/07/2025 18:06)
# ✅ Coletada: Comissão aprova autorização para motorista de apli... (04/07/2025 17:52)
# ✅ Coletada: Comissão aprova princípios de inclusão digital e a... (04/07/2025 17:30)
# ✅ Coletada: Comissão aprova competência de conselhos tutelares... (04/07/2025 16:47)
# 📊 Página 34: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 35: https://www.camara.leg.br/noticias/ultimas?pagina=35
# 📰 Encontradas 10 notícias na página 35
# ✅ Coletada: Seminário discute futuro das rádios legislativas e... (04/07/2025 16:32)
# ✅ Coletada: Comissão aprova projeto que prevê videomonitoramen... (04/07/2025 16:09)
# ✅ Coletada: Comissão aprova projeto que prioriza fiscalização ... (04/07/2025 16:02)
# ✅ Coletada: Comissão aprova programa de conectividade para áre... (04/07/2025 16:00)
# ✅ Coletada: Comissão aprova projeto que garante internação em ... (04/07/2025 15:57)
# ✅ Coletada: Comissão aprova criação de aplicativo para envio d... (04/07/2025 15:22)
# ✅ Coletada: Comissão aprova destinação de 20% dos recursos do ... (04/07/2025 14:50)
# ✅ Coletada: Comissão aprova novas regras para acessibilidade e... (04/07/2025 14:44)
# ✅ Coletada: Comissão aprova determinação de que escolas substi... (04/07/2025 14:18)
# ✅ Coletada: Deputados se antecipam a CPMI e cobram explicações... (04/07/2025 14:01)
# 📊 Página 35: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 36: https://www.camara.leg.br/noticias/ultimas?pagina=36
# 📰 Encontradas 10 notícias na página 36
# ✅ Coletada: Comissão aprova previsão de que gestante receba or... (04/07/2025 13:01)
# ✅ Coletada: Literatura acessível é tema de debate; confira em ... (04/07/2025 12:59)
# ✅ Coletada: Comissão aprova pena dobrada para compra de votos ... (04/07/2025 12:58)
# ✅ Coletada: Comissão aprova projeto que proíbe obsolescência p... (04/07/2025 11:34)
# ✅ Coletada: Hugo Motta elogia decisão de Moraes de suspender o... (04/07/2025 11:14)
# ✅ Coletada: Comissão aprova regra para veiculação de imagens e... (04/07/2025 11:03)
# ✅ Coletada: Comissão aprova projeto que facilita instalação de... (04/07/2025 10:21)
# ✅ Coletada: Comissão aprova projeto para dar mais eficiência a... (04/07/2025 10:06)
# ✅ Coletada: Comissão aprova projeto para conscientizar sobre p... (04/07/2025 08:48)
# ✅ Coletada: Cúpula dos Povos vai mobilizar participação social... (03/07/2025 20:06)
# 📊 Página 36: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 37: https://www.camara.leg.br/noticias/ultimas?pagina=37
# 📰 Encontradas 10 notícias na página 37
# ✅ Coletada: Representante do INSS confirma bloqueio de concess... (03/07/2025 19:36)
# ✅ Coletada: Comissão aprova incentivos e condições para o prim... (03/07/2025 19:19)
# ✅ Coletada: Comissão aprova proposta para facilitar exploração... (03/07/2025 18:50)
# ✅ Coletada: Diretores de TVs legislativas apontam desafios par... (03/07/2025 18:30)
# ✅ Coletada: Comissão aprova projeto que regulamenta a profissã... (03/07/2025 18:26)
# ✅ Coletada: Comissão aprova usar pequenas barragens para recup... (03/07/2025 17:35)
# ✅ Coletada: Comissão aprova proposta para aluno com diabetes t... (03/07/2025 17:17)
# ✅ Coletada: Comissão aprova proposta para levar energia elétri... (03/07/2025 16:44)
# ✅ Coletada: Meta de inflação de 3% ao ano é criticada em debat... (03/07/2025 16:19)
# ✅ Coletada: Comissão aprova incentivo a práticas sustentáveis ... (03/07/2025 15:31)
# 📊 Página 37: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 38: https://www.camara.leg.br/noticias/ultimas?pagina=38
# 📰 Encontradas 10 notícias na página 38
# ✅ Coletada: Comissão aprova inclusão de questões de gênero, ra... (03/07/2025 14:52)
# ✅ Coletada: Comissão aprova criação de programa de letramento ... (03/07/2025 14:41)
# ✅ Coletada: Comissão aprova aumento de pena para abandono de i... (03/07/2025 14:23)
# ✅ Coletada: Comissão aprova política de atendimento a brasilei... (03/07/2025 13:46)
# ✅ Coletada: Comissão aprova permissão para grávidas remarcarem... (03/07/2025 13:01)
# ✅ Coletada: Secretário de Comunicação defende ampliação do alc... (03/07/2025 12:14)
# ✅ Coletada: Comissão aprova classificação de crimes de violênc... (03/07/2025 12:11)
# ✅ Coletada: Comissão aprova projeto que regulariza funções com... (03/07/2025 12:10)
# ✅ Coletada: Câmara aprova criação de grupos parlamentares com ... (03/07/2025 10:23)
# ✅ Coletada: Comissão aprova projeto que beneficia agricultores... (03/07/2025 09:57)
# 📊 Página 38: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 39: https://www.camara.leg.br/noticias/ultimas?pagina=39
# 📰 Encontradas 10 notícias na página 39
# ✅ Coletada: Plenário da Câmara reúne-se nesta manhã para votar... (03/07/2025 08:48)
# ✅ Coletada: Seminário discute agenda política da Cúpula dos Po... (03/07/2025 08:16)
# ✅ Coletada: Comissão da Câmara discute denúncias de fraudes em... (03/07/2025 08:05)
# ✅ Coletada: Seminário debate experiências internacionais e liç... (03/07/2025 07:55)
# ✅ Coletada: Instalada comissão para analisar programa que agil... (02/07/2025 20:32)
# ✅ Coletada: Câmara aprova projeto que dificulta progressão de ... (02/07/2025 19:46)
# ✅ Coletada: Governo anuncia implantação da TV 3.0 até a Copa d... (02/07/2025 19:26)
# ✅ Coletada: Previdência diz que calendário de ressarcimento de... (02/07/2025 19:23)
# ✅ Coletada: Em audiência na Câmara, governo detalha os investi... (02/07/2025 18:57)
# ✅ Coletada: Câmara analisa projeto que dificulta progressão de... (02/07/2025 18:12)
# 📊 Página 39: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 40: https://www.camara.leg.br/noticias/ultimas?pagina=40
# 📰 Encontradas 10 notícias na página 40
# ✅ Coletada: Nova lei dispensa de reavaliações periódicas apose... (02/07/2025 17:46)
# ✅ Coletada: Deputados aprovam urgência para projeto sobre aval... (02/07/2025 17:09)
# ✅ Coletada: Defensores da causa palestina denunciam violações ... (02/07/2025 17:07)
# ✅ Coletada: Câmara analisa urgência para projeto do Senado sob... (02/07/2025 16:52)
# ✅ Coletada: Promulgada lei que prevê pagamento de pensão vital... (02/07/2025 16:51)
# ✅ Coletada: Marina Silva atribui aumento das queimadas a incên... (02/07/2025 16:13)
# ✅ Coletada: Comissão aprova regra para reiterar que estacionam... (02/07/2025 15:28)
# ✅ Coletada: Comissão aprova projeto que determina a busca imed... (02/07/2025 15:17)
# ✅ Coletada: Debatedores defendem inserção de sistemas de armaz... (02/07/2025 14:13)
# ✅ Coletada: Projeto abre crédito orçamentário de R$ 8,3 bilhõe... (02/07/2025 14:00)
# 📊 Página 40: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 41: https://www.camara.leg.br/noticias/ultimas?pagina=41
# 📰 Encontradas 10 notícias na página 41
# ✅ Coletada: Cancelado debate sobre o risco de sobrecarga na re... (02/07/2025 13:57)
# ✅ Coletada: Projeto suplementa recursos para o programa Pé-de-... (02/07/2025 13:52)
# ✅ Coletada: Comissão aprova projeto que aumenta penas para cri... (02/07/2025 13:42)
# ✅ Coletada: Projeto altera LDO de 2025 para facilitar repasses... (02/07/2025 12:55)
# ✅ Coletada: Debatedores alertam para aumento de casos de bully... (02/07/2025 12:54)
# ✅ Coletada: Comissão aprova proibição de sigilo de gastos públ... (02/07/2025 12:21)
# ✅ Coletada: Motta agradece apoio após gestão ser bem avaliada ... (02/07/2025 12:03)
# ✅ Coletada: Câmara recebe mais de 400 propostas antirracistas ... (02/07/2025 10:49)
# ✅ Coletada: Motta afirma que foco da reforma administrativa é ... (02/07/2025 09:41)
# ✅ Coletada: Plenário pode votar hoje projeto que reforça medid... (02/07/2025 09:34)
# 📊 Página 41: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 42: https://www.camara.leg.br/noticias/ultimas?pagina=42
# 📰 Encontradas 10 notícias na página 42
# ✅ Coletada: Em Lisboa, Motta destaca desafios ambientais e tec... (02/07/2025 09:25)
# ✅ Coletada: Comissão debate alimentação escolar nos institutos... (02/07/2025 08:40)
# ✅ Coletada: Comissão debate cenário da previdência complementa... (02/07/2025 08:26)
# ✅ Coletada: Comissão debate irregularidades em empréstimos con... (02/07/2025 08:22)
# ✅ Coletada: Ministro das Comunicações participa na Câmara de d... (02/07/2025 08:21)
# ✅ Coletada: Comissão do Esporte debate regras para uso de pist... (02/07/2025 08:15)
# ✅ Coletada: Comissão debate preparativos para a marcha naciona... (02/07/2025 08:11)
# ✅ Coletada: Comissão de Agricultura ouve ministra Marina Silva... (02/07/2025 08:10)
# ✅ Coletada: Comissão realiza audiência para debater gastos e g... (02/07/2025 08:03)
# ✅ Coletada: Comissão discute criação de zonas de processamento... (02/07/2025 07:55)
# 📊 Página 42: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 43: https://www.camara.leg.br/noticias/ultimas?pagina=43
# 📰 Encontradas 10 notícias na página 43
# ✅ Coletada: Comissão debate sistemas de armazenamento de energ... (02/07/2025 07:52)
# ✅ Coletada: Projeto cria área especial de interesse turístico ... (01/07/2025 20:20)
# ✅ Coletada: Especialistas apostam em objetivo do PNE que busca... (01/07/2025 20:19)
# ✅ Coletada: Câmara aprova projeto que prevê cálculo do valor d... (01/07/2025 19:06)
# ✅ Coletada: Comissão aprova criminalização da posse de celular... (01/07/2025 18:55)
# ✅ Coletada: Entra em vigor lei que isenta cosméticos e perfume... (01/07/2025 18:50)
# ✅ Coletada: Comissão aprova projeto que deixa de considerar mo... (01/07/2025 18:48)
# ✅ Coletada: CCJ aprova projeto que regulamenta vistoria em imó... (01/07/2025 18:23)
# ✅ Coletada: Comissão aprova aumento para aquisição de armas de... (01/07/2025 18:05)
# ✅ Coletada: Representantes de carreiras jurídicas pedem mais r... (01/07/2025 18:03)
# 📊 Página 43: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 44: https://www.camara.leg.br/noticias/ultimas?pagina=44
# 📰 Encontradas 10 notícias na página 44
# ✅ Coletada: Comissão aprova aumento da pena de tráfico de drog... (01/07/2025 17:57)
# ✅ Coletada: Líder do governo diz que recurso à Justiça sobre I... (01/07/2025 17:46)
# ✅ Coletada: CCJ aprova garantia de aposentadoria rural para mu... (01/07/2025 17:43)
# ✅ Coletada: Setor produtivo pede ao STF que mantenha decisão d... (01/07/2025 17:41)
# ✅ Coletada: Deputados analisam projeto que prevê cálculo do va... (01/07/2025 17:22)
# ✅ Coletada: Encontro da Rede Legislativa de Rádio e TV discute... (01/07/2025 17:13)
# ✅ Coletada: Câmara aprova MP que libera R$ 520 milhões para aç... (01/07/2025 17:12)
# ✅ Coletada: Especialistas dizem que Sistema Nacional de Cultur... (01/07/2025 16:49)
# ✅ Coletada: Decisão do governo de recorrer contra derrubada de... (01/07/2025 16:43)
# ✅ Coletada: CCJ aprova licença-maternidade para atletas, inclu... (01/07/2025 16:41)
# 📊 Página 44: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 45: https://www.camara.leg.br/noticias/ultimas?pagina=45
# 📰 Encontradas 10 notícias na página 45
# ✅ Coletada: CCJ aprova regra sobre dissolução do casamento no ... (01/07/2025 16:27)
# ✅ Coletada: Deputados analisam MP que libera R$ 520 milhões pa... (01/07/2025 16:14)
# ✅ Coletada: Fabio Schiochet é eleito presidente do Conselho de... (01/07/2025 16:01)
# ✅ Coletada: Comissão aprova proposta que cria categorias de pe... (01/07/2025 15:51)
# ✅ Coletada: Comissão aprova proibição de progressão de regime ... (01/07/2025 15:49)
# ✅ Coletada: Reforma administrativa: acadêmicos sugerem avaliaç... (01/07/2025 15:43)
# ✅ Coletada: Proposta permite propaganda eleitoral em duas líng... (01/07/2025 14:45)
# ✅ Coletada: Em debate, governo contesta críticas à saúde finan... (01/07/2025 14:03)
# ✅ Coletada: Lei incentiva empreendedorismo de pessoas com defi... (01/07/2025 13:22)
# ✅ Coletada: Projeto determina que 3% das emendas impositivas s... (01/07/2025 11:30)
# 📊 Página 45: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 46: https://www.camara.leg.br/noticias/ultimas?pagina=46
# 📰 Encontradas 10 notícias na página 46
# ✅ Coletada: Cancelada audiência com a ministra Simone Tebet so... (01/07/2025 09:09)
# ✅ Coletada: Comissão debate situação do departamento de audito... (01/07/2025 08:56)
# ✅ Coletada: Audiência na Câmara discute a Política Nacional de... (01/07/2025 08:37)
# ✅ Coletada: Conselho de Ética da Câmara será instalado e elege... (01/07/2025 08:32)
# ✅ Coletada: Comissão de Agricultura debate endividamento de pr... (01/07/2025 08:30)
# ✅ Coletada: Comissão especial discute financiamento e infraest... (01/07/2025 08:30)
# ✅ Coletada: Câmara pode votar nesta terça-feira MP que libera ... (01/07/2025 08:28)
# ✅ Coletada: Comissão debate inclusão de diretrizes para uma ed... (01/07/2025 08:24)
# ✅ Coletada: Grupo de trabalho da reforma administrativa ouve e... (01/07/2025 08:22)
# ✅ Coletada: Comissão avalia ações do governo para pessoas com ... (01/07/2025 08:20)
# 📊 Página 46: 10 válidas, 0 anteriores ao limite
# 📄 Processando página 47: https://www.camara.leg.br/noticias/ultimas?pagina=47
# 📰 Encontradas 10 notícias na página 47
# ✅ Coletada: Comissão de Defesa dos Direitos das Pessoas com De... (01/07/2025 08:17)
# ✅ Coletada: Comissão de Meio Ambiente debate cooperativismo e ... (01/07/2025 08:12)
# ✅ Coletada: Comissão debate futuro da linha férrea Tronco Sul ... (01/07/2025 08:09)
# ✅ Coletada: Comissão recebe secretária do governo para apresen... (01/07/2025 08:07)
# ✅ Coletada: Comissão debate repressão no campo durante a ditad... (01/07/2025 08:06)
# ✅ Coletada: Comissão de Cultura debate a regulamentação do Sis... (01/07/2025 08:00)
# ⏰ Notícia anterior ao limite: 30/06/2025 19:22
# ⏰ Notícia anterior ao limite: 30/06/2025 19:04
# ⏰ Notícia anterior ao limite: 30/06/2025 18:29
# ⏰ Notícia anterior ao limite: 30/06/2025 18:06
# 📊 Página 47: 6 válidas, 4 anteriores ao limite
# 📄 Processando página 48: https://www.camara.leg.br/noticias/ultimas?pagina=48
# 📰 Encontradas 10 notícias na página 48
# ⏰ Notícia anterior ao limite: 30/06/2025 17:48
# ⏰ Notícia anterior ao limite: 30/06/2025 17:26
# ...
# 📰 Encontradas 27 notícias na página 23
# ✅ Coletada: Senado aprova mesmos direitos de PcD a pacientes d... (02/07/2025 21h43)
# ✅ Coletada: Aprovada audiência para ouvir Marina Silva sobre e... (02/07/2025 21h36)
# ✅ Coletada: Indígenas e quilombolas devem escolher os nomes da... (02/07/2025 21h31)
# ✅ Coletada: Comunidades tradicionais poderão ter o direito de ... (02/07/2025 21h27)
# ✅ Coletada: Debate na CDR aponta entraves no acesso de municíp... (02/07/2025 21h27)
# ✅ Coletada: Senado aprova: fibromialgia como deficiência e inc... (02/07/2025 21h22)
# ✅ Coletada: Consignado privado: regulação é aprovada com inclu... (02/07/2025 21h17)
# ✅ Coletada: Projeto de política de governança na administração... (02/07/2025 21h15)
# ✅ Coletada: CRA vai debater regulamentação e fiscalização do t... (02/07/2025 21h06)
# ✅ Coletada: Acordo internacional facilita visto para Europa... (02/07/2025 20h57)
# ✅ Coletada: Subcomissão quer informações de Marina Silva sobre... (02/07/2025 20h53)
# ✅ Coletada: Senado aprova incentivo à circulação de talentos e... (02/07/2025 20h48)
# ✅ Coletada: Cleitinho defende prerrogativas do Congresso e cri... (02/07/2025 20h44)
# ✅ Coletada: Aprovado acordo que facilita mobilidade de talento... (02/07/2025 20h40)
# ✅ Coletada: Sessão solene vai celebrar os 125 anos da Fundação... (02/07/2025 20h36)
# ✅ Coletada: Senado aprova acordos internacionais nas áreas de ... (02/07/2025 20h26)
# ✅ Coletada: Aprovada MP sobre crédito consignado para trabalha... (02/07/2025 20h25)
# ✅ Coletada: Debatedoras defendem trabalho integrado de observa... (02/07/2025 20h23)
# ✅ Coletada: Política para pesca sustentável segue para a CMA... (02/07/2025 20h20)
# ✅ Coletada: Senado terá frente parlamentar em prol do setor ná... (02/07/2025 20h00)
# 📊 Página 23: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 24: https://www12.senado.leg.br/noticias/ultimas/24
# 📰 Encontradas 27 notícias na página 24
# ✅ Coletada: Senado aprova tratado Brasil-Ucrânia para acesso d... (02/07/2025 19h46)
# ✅ Coletada: Senado aprova benefício fiscal para micro e pequen... (02/07/2025 19h36)
# ✅ Coletada: Penas maiores para crimes sexuais contra crianças ... (02/07/2025 19h33)
# ✅ Coletada: Comissão aprova compensação de déficit de Reserva ... (02/07/2025 19h18)
# ✅ Coletada: Jovem Senador divulga lista de estudantes selecion... (02/07/2025 18h55)
# ✅ Coletada: Crédito consignado para trabalhador do setor priva... (02/07/2025 18h54)
# ✅ Coletada: Mobilidade de pesquisadores:O Plenário aprovou a C... (02/07/2025 18h48)
# ✅ Coletada: Acordo Brasil-Ucrânia:Senadoras e senadores aprova... (02/07/2025 18h47)
# ✅ Coletada: Senadores e deputados avaliam audiência com direto... (02/07/2025 18h44)
# ✅ Coletada: Acredita Exportação:O Senado aprovou o PLP 167/202... (02/07/2025 18h37)
# ✅ Coletada: Avança projeto que garante acesso à agua e aliment... (02/07/2025 18h31)
# ✅ Coletada: CRE aprova convite a ministro da Defesa e comandan... (02/07/2025 18h06)
# ✅ Coletada: Vai à Plenário projeto que torna ações de conscien... (02/07/2025 18h03)
# ✅ Coletada: Senado instala Frente Parlamentar em Defesa do Pet... (02/07/2025 17h54)
# ✅ Coletada: Crédito Consignado:O Plenário do Senado aprovou do... (02/07/2025 17h53)
# ✅ Coletada: CE reconhece carnaval do Rio de Janeiro como manif... (02/07/2025 17h47)
# ✅ Coletada: Projeto que cria Dia Nacional da Axé-Music vai à s... (02/07/2025 17h45)
# ✅ Coletada: Instalada Comissão da MP que cria programa para ag... (02/07/2025 17h43)
# ✅ Coletada: Humberto critica derrubada de decreto e cobra just... (02/07/2025 17h31)
# ✅ Coletada: Política de governança da administração pública av... (02/07/2025 17h31)
# 📊 Página 24: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 25: https://www12.senado.leg.br/noticias/ultimas/25
# 📰 Encontradas 27 notícias na página 25
# ✅ Coletada: Comissão debate ampliação da Lei de Incentivo ao E... (02/07/2025 17h26)
# ✅ Coletada: Fibromialgia será considerada deficiência, determi... (02/07/2025 17h22)
# ✅ Coletada: Izalci cobra fiscalização das apostas on-line e cr... (02/07/2025 17h10)
# ✅ Coletada: Esperidião Amin alerta para fragilidade das agênci... (02/07/2025 17h06)
# ✅ Coletada: CRE aprova projeto que esclarece isenção de visto ... (02/07/2025 17h04)
# ✅ Coletada: Plínio  cobra votação de PEC que limita mandato de... (02/07/2025 16h57)
# ✅ Coletada: Fibromialgia:O Senado aprovou o Projeto de Lei 3.0... (02/07/2025 16h54)
# ✅ Coletada: Paim destaca aprovação de MP que amplia uso do Fun... (02/07/2025 16h52)
# ✅ Coletada: CRE aprova adesão do Brasil à nova fase do fundo d... (02/07/2025 16h47)
# ✅ Coletada: PEC para fortalecer educação passa pela terceira s... (02/07/2025 16h45)
# ✅ Coletada: Regras para nomes de escolas indígenas e quilombol... (02/07/2025 16h44)
# ✅ Coletada: CRE aprova acordo com Polônia para evitar dupla tr... (02/07/2025 16h07)
# ✅ Coletada: CRE aprova indicações para embaixadas na Europa, n... (02/07/2025 15h46)
# ✅ Coletada: Educadores defendem metas realistas e papel do set... (02/07/2025 15h15)
# ✅ Coletada: Vai a Plenário acordo internacional sobre subsídio... (02/07/2025 14h49)
# ✅ Coletada: Plenário votará a indicação de seis novos embaixad... (02/07/2025 14h46)
# ✅ Coletada: Adesão a novas regras da Organização Marítima Inte... (02/07/2025 14h45)
# ✅ Coletada: Comissão de Direitos Humanos aprova aumento da pen... (02/07/2025 14h42)
# ✅ Coletada: Duas faltas anuais ao trabalho para quem doar sang... (02/07/2025 14h36)
# ✅ Coletada: Oferta de equoterapia no SUS segue para votação em... (02/07/2025 14h18)
# 📊 Página 25: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 26: https://www12.senado.leg.br/noticias/ultimas/26
# 📰 Encontradas 27 notícias na página 26
# ✅ Coletada: CTFC fará auditoria sobre atuação do BB com foco n... (02/07/2025 14h14)
# ✅ Coletada: Aumento de pena para crimes sexuais contra vulnerá... (02/07/2025 13h24)
# ✅ Coletada: Política de governança da administração pública va... (02/07/2025 12h59)
# ✅ Coletada: Prioridade de atendimento à pessoa com Parkinson v... (02/07/2025 12h54)
# ✅ Coletada: Selo 'Cidade Mulher' vai a Plenário... (02/07/2025 12h37)
# ✅ Coletada: CAS fará audiência sobre crise na saúde pública no... (02/07/2025 12h22)
# ✅ Coletada: CAS aprova programa de prevenção à depressão... (02/07/2025 12h13)
# ✅ Coletada: Duas faltas ao trabalho para doar sangue têm a apr... (02/07/2025 12h07)
# ✅ Coletada: Bloqueio do Fundo Nacional para a Criança e o Adol... (02/07/2025 12h00)
# ✅ Coletada: CAS aprova isenção do IR para aposentadas com doen... (02/07/2025 11h53)
# ✅ Coletada: CAS aprova Agosto Azul e Vermelho para orientar po... (02/07/2025 11h48)
# ✅ Coletada: Pensão a vítimas do Zika vírus agora é lei... (02/07/2025 11h27)
# ✅ Coletada: Vai ao Plenário inclusão da equoterapia nas prátic... (02/07/2025 11h04)
# ✅ Coletada: Marinho defende princípios da direita e critica po... (02/07/2025 10h30)
# ✅ Coletada: Dispensa de reavaliação de aposentados por incapac... (02/07/2025 10h23)
# ✅ Coletada: Projeto obriga pais a supervisionarem o uso da int... (02/07/2025 09h19)
# ✅ Coletada: CMA aprova penas maiores para garimpo ilegal e des... (01/07/2025 21h34)
# ✅ Coletada: Senadores repercutem ação no STF para reverter a a... (01/07/2025 21h29)
# ✅ Coletada: Aprovada política para incentivar permanência de j... (01/07/2025 21h24)
# ✅ Coletada: Paim questiona críticas ao IOF diante do aumento d... (01/07/2025 21h23)
# 📊 Página 26: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 27: https://www12.senado.leg.br/noticias/ultimas/27
# 📰 Encontradas 27 notícias na página 27
# ✅ Coletada: Saneamento: ampliação depende de melhor distribuiç... (01/07/2025 21h19)
# ✅ Coletada: Senado amplia destinação de recursos do Fundo Soci... (01/07/2025 21h13)
# ✅ Coletada: Girão denuncia perseguição política em cassação do... (01/07/2025 21h12)
# ✅ Coletada: Plenário aprova protocolo da OIT contra trabalho f... (01/07/2025 21h11)
# ✅ Coletada: CCJ vai analisar ampliação da legítima defesa... (01/07/2025 21h09)
# ✅ Coletada: Aproveitamento de concurso e mudança em cargos do ... (01/07/2025 21h03)
# ✅ Coletada: Mudanças na destinação do Fundo Social seguem para... (01/07/2025 20h58)
# ✅ Coletada: Após licença de Vanderlan, Pedro Chaves assume vag... (01/07/2025 20h53)
# ✅ Coletada: Aprovada criação de varas federais e cargos em San... (01/07/2025 20h47)
# ✅ Coletada: Senado aprova política para manter jovens agricult... (01/07/2025 20h36)
# ✅ Coletada: Mães vítimas de violência doméstica no exterior pe... (01/07/2025 20h35)
# ✅ Coletada: Debate aponta que sem apoio municípios menores não... (01/07/2025 20h26)
# ✅ Coletada: Confúcio diz que dívida pública ameaça investiment... (01/07/2025 20h08)
# ✅ Coletada: Senado recebe exposição de 200 anos da Confederaçã... (01/07/2025 20h02)
# ✅ Coletada: PEC da Educação como vetor de progresso passa por ... (01/07/2025 20h02)
# ✅ Coletada: Fundo Social:O Senado aprovou a Medida Provisória ... (01/07/2025 19h49)
# ✅ Coletada: Quarentena para ex-diretores do BC gera debate no ... (01/07/2025 19h34)
# ✅ Coletada: Pedro Chaves toma posse como senador por Goiás... (01/07/2025 19h02)
# ✅ Coletada: Kajuru apresenta projeto para combater fraudes em ... (01/07/2025 18h41)
# ✅ Coletada: Adiada reunião da comissão da MP que melhora servi... (01/07/2025 18h39)
# 📊 Página 27: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 28: https://www12.senado.leg.br/noticias/ultimas/28
# 📰 Encontradas 27 notícias na página 28
# ✅ Coletada: Especialistas discutem desafios legislativos para ... (01/07/2025 18h34)
# ✅ Coletada: Historiadores destacam méritos da Confederação do ... (01/07/2025 18h32)
# ✅ Coletada: Augusta apresenta projetos para aumentar controle ... (01/07/2025 18h31)
# ✅ Coletada: CRA pode votar compensação ambiental em dobro e co... (01/07/2025 18h29)
# ✅ Coletada: Brasil deve acelerar política de minerais críticos... (01/07/2025 18h22)
# ✅ Coletada: Lucas Barreto critica ação do MPF contra exploraçã... (01/07/2025 18h12)
# ✅ Coletada: Styvenson questiona locação de computadores para e... (01/07/2025 18h08)
# ✅ Coletada: Senado entrega primeira edição da Comenda Chico Xa... (01/07/2025 17h57)
# ✅ Coletada: Zequinha Marinho destaca qualificação de mulheres ... (01/07/2025 17h56)
# ✅ Coletada: CMA aprova aumento da pena para crime de poluição ... (01/07/2025 17h33)
# ✅ Coletada: Damares relata casos de abuso e tráfico infantil d... (01/07/2025 17h15)
# ✅ Coletada: CCJ pode votar na próxima semana fim da restrição ... (01/07/2025 17h07)
# ✅ Coletada: Adiada votação de incentivo fiscal para exportaçõe... (01/07/2025 17h02)
# ✅ Coletada: Projeto que aproveita concurso e transforma cargos... (01/07/2025 16h57)
# ✅ Coletada: Izalci Lucas defende educação como política de Est... (01/07/2025 16h57)
# ✅ Coletada: CAS debate criação da Rede Nacional de Observatóri... (01/07/2025 16h52)
# ✅ Coletada: Brasil não mapeou seu potencial em minerais crític... (01/07/2025 16h32)
# ✅ Coletada: CI aprova prestação de contas separada para royalt... (01/07/2025 16h29)
# ✅ Coletada: CAS vai remarcar audiência sobre venda de medicame... (01/07/2025 16h14)
# ✅ Coletada: CCJ aprova projeto que aproveita concurso e transf... (01/07/2025 16h04)
# 📊 Página 28: 20 válidas, 0 anteriores ao limite
# 📄 Processando página 29: https://www12.senado.leg.br/noticias/ultimas/29
# 📰 Encontradas 27 notícias na página 29
# ✅ Coletada: Plínio Valério denuncia ações contra produtores ru... (01/07/2025 16h01)
# ✅ Coletada: Debate pede gestão compartilhada no combate a "cer... (01/07/2025 16h00)
# ✅ Coletada: Debatedores pedem ajustes no projeto de acesso às ... (01/07/2025 15h57)
# ✅ Coletada: CCJ aprova criação de varas federais e cargos em S... (01/07/2025 15h54)
# ✅ Coletada: Debatedores na CAE defendem mineração como estraté... (01/07/2025 15h49)
# ✅ Coletada: CI discutirá impacto de cortes orçamentários em ag... (01/07/2025 14h07)
# ✅ Coletada: Comissão aprova nova hipótese de legítima defesa p... (01/07/2025 13h27)
# ✅ Coletada: Dados sobre crime organizado devem integrar sistem... (01/07/2025 13h02)
# ✅ Coletada: CI: projeto exige transparência no uso de recursos... (01/07/2025 12h17)
# ✅ Coletada: CSP amplia legítima defesa em casos de reação a in... (01/07/2025 12h16)
# ✅ Coletada: Aumento de penas para crimes ligados ao garimpo il... (01/07/2025 11h42)
# ✅ Coletada: Lei isenta cosméticos e perfumes artesanais de reg... (01/07/2025 11h32)
# ✅ Coletada: Criação de frente parlamentar do setor náutico seg... (01/07/2025 11h30)
# ✅ Coletada: CMA aprova aumento de pena para responsáveis por d... (01/07/2025 11h03)
# ✅ Coletada: Lei incentiva empreendedorismo de pessoas com defi... (01/07/2025 10h29)
# ✅ Coletada: Código Eleitoral: Marcelo Castro propõe regulação ... (01/07/2025 08h56)
# ✅ Coletada: Projeto cria metas de desempenho em atendimento de... (01/07/2025 08h50)
# ⏰ Notícia anterior ao limite: 30/06/2025 18h59
# ⏰ Notícia anterior ao limite: 30/06/2025 18h49
# ⏰ Notícia anterior ao limite: 30/06/2025 18h37
# 📊 Página 29: 17 válidas, 3 anteriores ao limite
# 📄 Processando página 30: https://www12.senado.leg.br/noticias/ultimas/30
# 📰 Encontradas 27 notícias na página 30
# ⏰ Notícia anterior ao limite: 30/06/2025 18h07
# ⏰ Notícia anterior ao limite: 30/06/2025 17h58
# ⏰ Notícia anterior ao limite: 30/06/2025 17h39
# ⏰ Notícia anterior ao limite: 30/06/2025 17h08
# ⏰ Notícia anterior ao limite: 30/06/2025 16h36
# ⏰ Notícia anterior ao limite: 30/06/2025 16h28
# ⏰ Notícia anterior ao limite: 30/06/2025 15h39
# ⏰ Notícia anterior ao limite: 30/06/2025 15h36
# ⏰ Notícia anterior ao limite: 30/06/2025 15h31
# ⏰ Notícia anterior ao limite: 30/06/2025 14h48
# ⏰ Notícia anterior ao limite: 30/06/2025 14h08
# ⏰ Notícia anterior ao limite: 30/06/2025 13h47
# ⏰ Notícia anterior ao limite: 30/06/2025 13h28
# ⏰ Notícia anterior ao limite: 30/06/2025 13h24
# ⏰ Notícia anterior ao limite: 30/06/2025 13h23
# ⏰ Notícia anterior ao limite: 30/06/2025 11h14
# ⏰ Notícia anterior ao limite: 30/06/2025 11h03
# ⏰ Notícia anterior ao limite: 30/06/2025 10h36
# ⏰ Notícia anterior ao limite: 30/06/2025 10h35
# ⏰ Notícia anterior ao limite: 30/06/2025 10h03
# 📊 Página 30: 0 válidas, 20 anteriores ao limite
# 🎯 Atingiu o limite temporal na página 30. Parando coleta do Senado.
# ✅ Senado: Coleta completa desde 01/07/2025 - 577 notícias coletadas
#
# ============================================================
# 📊 RESUMO DA COLETA HISTÓRICA:
# 🏛️ Câmara dos Deputados: 466 notícias
# 🏛️ Senado Federal: 577 notícias
# 📈 Total coletado: 1043 notícias
# 📅 Período coberto: 01/07/2025 a 18/07/2025
#
# 📋 PREVIEW DOS DADOS:
#                   fonte                                             titulo  \
# 0  Câmara dos Deputados  Comissão aprova proposta de estímulo fiscal pa...
# 1  Câmara dos Deputados  Comissão aprova projeto que obriga serviços de...
# 2        Senado Federal  Sancionada homenagem a José Pereira da Silva e...
# 3  Câmara dos Deputados  Projeto cria novo marco legal do transporte in...
# 4        Senado Federal  Senado deve analisar Fundo Social do pré-sal p...
# 5  Câmara dos Deputados  Comissão aprova projeto que prevê uso de algor...
# 6        Senado Federal  Senado analisa ampliação de alertas sobre desa...
# 7  Câmara dos Deputados  Hugo Motta e Davi Alcolumbre confirmam recesso...
# 8        Senado Federal  Sancionada lei que altera denominação de trech...
# 9  Câmara dos Deputados  Oposição acusa Moraes de "abuso de autoridade"...
#
#       data_publicacao
# 0 2025-07-18 18:28:00
# 1 2025-07-18 18:09:00
# 2 2025-07-18 17:38:00
# 3 2025-07-18 17:31:00
# 4 2025-07-18 17:16:00
# 5 2025-07-18 16:57:00
# 6 2025-07-18 16:47:00
# 7 2025-07-18 16:29:00
# 8 2025-07-18 16:25:00
# 9 2025-07-18 16:09:00
#
# 📊 ESTATÍSTICAS:
# Período: 2025-07-01 08:00:00 a 2025-07-18 18:28:00
# Distribuição por fonte:
# fonte
# Senado Federal          577
# Câmara dos Deputados    466
# Name: count, dtype: int64
# 💾 Arquivo salvo: clipping_legislativo_20250721_031549.csv
#
# ✅ Coleta finalizada com sucesso!
# 📁 Dados disponíveis no DataFrame 'df' e no arquivo 'clipping_legislativo_20250721_031549.csv'
#
# 📅 ATENÇÃO: Não chegou até 01/07/2025 (parou em 01/07/2025)
# 💡 Dica: Aumente o número de páginas para coletar mais histórico.
# 💡 Exemplo: clipping.executar_coleta_completa(max_pages_camara=60, max_pages_senado=60)

# %%
pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.2.2-py3-none-any.whl.metadata (3.8 kB)
# Downloading schedule-1.2.2-py3-none-any.whl (12 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.2.2

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import pandas as pd
from datetime import datetime
import re
from pathlib import Path

DB_PATH = "clipping_faciap_textos.db"

# Inicializa banco de dados
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS textos_completos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        url TEXT UNIQUE,
        fonte TEXT,
        titulo TEXT,
        data_publicacao TEXT,
        texto_completo TEXT,
        num_palavras INTEGER,
        coletado_em TEXT
    )
''')

conn.commit()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

def extrair_texto(url):
    try:
        response = requests.get(url, headers=headers, timeout=20)
        soup = BeautifulSoup(response.content, 'html.parser')

        for tag in soup(['script','style','nav','footer','header','aside','video','audio','iframe']):
            tag.decompose()

        texto = None

        if 'camara.leg.br' in url:
            container = soup.find('div', id='content-noticia')
            if container:
                texto = ' '.join([p.get_text(strip=True) for p in container.find_all('p')])

        elif 'senado.leg.br' in url:
            container = (soup.find('div', id='textoMateria') or
                         soup.find('div', class_='texto-materia') or
                         soup.find('div', class_='conteudo-materia'))
            if container:
                texto = ' '.join([p.get_text(strip=True) for p in container.find_all('p')])

        if not texto or len(texto.split()) < 50:
            paragrafos = soup.find_all('p')
            texto = ' '.join([p.get_text(strip=True) for p in paragrafos if len(p.get_text(strip=True)) > 40])

        if texto and len(texto.split()) > 20:
            return texto.strip()
        else:
            return None

    except Exception as e:
        return None

def processar_csv(arquivo):
    df = pd.read_csv(arquivo, encoding='ISO-8859-1', sep=',')
    sucessos = 0
    for _, row in df.iterrows():
        url = row['link']
        if not url:
            continue

        texto = extrair_texto(url)
        if texto:
            conn = sqlite3.connect(DB_PATH)
            cursor = conn.cursor()

            cursor.execute('''
                INSERT OR IGNORE INTO textos_completos (url, fonte, titulo, data_publicacao, texto_completo, num_palavras, coletado_em)
                VALUES (?, ?, ?, ?, ?, ?, ?)
            ''', (
                url,
                row.get('fonte', ''),
                row.get('titulo', ''),
                row.get('data_publicacao', ''),
                texto,
                len(texto.split()),
                datetime.now().isoformat()
            ))
            conn.commit()
            conn.close()
            sucessos += 1
            print(f"✅ Texto extraído ({len(texto.split())} palavras) - {url}")
        else:
            print(f"❌ Falha na extração - {url}")
    print(f"\n🎯 Total de textos coletados com sucesso: {sucessos}")

# Exemplo de uso
if __name__ == '__main__':
    caminho_csv = "clipping_legislativo_20250721_031549.csv"
    if Path(caminho_csv).exists():
        processar_csv(caminho_csv)
    else:
        print("Arquivo CSV não encontrado.")
# Out:
# ✅ Texto extraído (556 palavras) - https://www.camara.leg.br/noticias/1182032-comissao-aprova-proposta-de-estimulo-fiscal-para-pesquisa-de-racao-sustentavel/
# ✅ Texto extraído (602 palavras) - https://www.camara.leg.br/noticias/1182017-comissao-aprova-projeto-que-obriga-servicos-de-saude-a-assegurar-mamografia-a-mulheres-com-deficiencia/
# ✅ Texto extraído (179 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/sancionada-homenagem-a-jose-pereira-da-silva-em-viaduto-em-pouso-alegre
# ✅ Texto extraído (1428 palavras) - https://www.camara.leg.br/noticias/1181948-projeto-cria-novo-marco-legal-do-transporte-individual-por-aplicativo-no-pais/
# ✅ Texto extraído (1397 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/senado-deve-analisar-fundo-social-do-pre-sal-para-agricultores-em-calamidades
# ✅ Texto extraído (898 palavras) - https://www.camara.leg.br/noticias/1182008-comissao-aprova-projeto-que-preve-uso-de-algoritmos-no-combate-a-crimes-digitais-contra-criancas-e-adolescentes/
# ✅ Texto extraído (303 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/senado-analisa-ampliacao-de-alertas-sobre-desaparecidos
# ✅ Texto extraído (243 palavras) - https://www.camara.leg.br/noticias/1182055-hugo-motta-e-davi-alcolumbre-confirmam-recesso-parlamentar-nas-proximas-duas-semanas/
# ✅ Texto extraído (148 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/sancionada-lei-que-altera-denominacao-de-trechos-da-br-158
# ✅ Texto extraído (1137 palavras) - https://www.camara.leg.br/noticias/1181942-oposicao-acusa-moraes-de-abuso-de-autoridade-lider-do-pt-comemora-vitoria-do-estado-de-direito/
# ✅ Texto extraído (327 palavras) - https://www.camara.leg.br/noticias/1181846-camara-cria-comissao-para-analisar-regulamentacao-do-trabalho-de-motorista-de-aplicativo/
# ✅ Texto extraído (73 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/licenciamento-ambiental-aguarda-sancao-e-divide-opinioes
# ✅ Texto extraído (1392 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/oposicao-reage-as-medidas-do-stf-contra-bolsonaro-governistas-defendem-decisao
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/infomaterias/2025/07/leis-garantem-direitos-aos-autistas
# ✅ Texto extraído (833 palavras) - https://www.camara.leg.br/noticias/1146575-projeto-propoe-medidas-contra-assedio-e-violencia-misoginos-no-trabalho/
# ✅ Texto extraído (657 palavras) - https://www.camara.leg.br/noticias/1173973-proposta-amplia-limite-de-receita-bruta-para-transportador-de-cargas-mei/
# ✅ Texto extraído (122 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/iof-oposicao-espera-que-plenario-do-stf-reveja-decisao-de-moraes
# ✅ Texto extraído (474 palavras) - https://www.camara.leg.br/noticias/1147123-projeto-determina-a-instalacao-de-cameras-de-seguranca-em-carros-de-aplicativo/
# ✅ Texto extraído (85 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/mara-gabrilli-critica-demora-do-governo-em-indenizacao-a-vitimas-do-zika-virus
# ✅ Texto extraído (1906 palavras) - https://www12.senado.leg.br/noticias/infomaterias/2025/07/guilherme-edita-codigo-eleitoral-completa-60-anos-legado-desafios-e-futuro
# ✅ Texto extraído (380 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/senado-aprova-aumento-de-incentivos-fiscais-ao-esporte
# ✅ Texto extraído (300 palavras) - https://www.camara.leg.br/noticias/1181691-lei-cria-rota-turistica-em-litoral-de-santa-catarina/
# ✅ Texto extraído (352 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/lei-amplia-direito-de-cirurgia-de-reconstrucao-de-mama-pelo-sus
# ✅ Texto extraído (378 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/agora-e-lei-assistencia-estudantil-tera-recursos-do-fundo-social-do-petroleo
# ✅ Texto extraído (208 palavras) - https://www.camara.leg.br/noticias/1181687-lei-cria-a-rota-turistica-imperial-caminho-dos-principes-em-santa-catarina/
# ✅ Texto extraído (634 palavras) - https://www.camara.leg.br/noticias/1181840-taxacao-dos-eua-continua-dividindo-opinioes-na-camara-dos-deputados/
# ✅ Texto extraído (632 palavras) - https://www.camara.leg.br/noticias/1181707-comissao-aprova-ampliacao-dos-recursos-do-fundo-nacional-do-idoso/
# ✅ Texto extraído (514 palavras) - https://www.camara.leg.br/noticias/1181717-comissao-aprova-prisao-preventiva-de-familiares-que-cometerem-crimes-sexuais-contra-criancas-e-adolescentes/
# ✅ Texto extraído (507 palavras) - https://www.camara.leg.br/noticias/1181518-comissao-aprova-identificacao-de-quem-tem-doenca-renal-cronica-como-pessoa-com-deficiencia/
# ✅ Texto extraído (532 palavras) - https://www.camara.leg.br/noticias/1181710-comissao-aprova-garantia-de-suplementacao-alimentar-a-idoso-internado-e-com-desnutricao/
# ✅ Texto extraído (598 palavras) - https://www.camara.leg.br/noticias/1181495-comissao-aprova-medida-que-reforca-o-direito-de-autistas-ao-diagnostico-precoce/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1181733-comissao-aprova-programas-de-visitacao-de-criancas-e-adolescentes-orfaos-a-idosos-em-asilos/
# ✅ Texto extraído (1007 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/ampliacao-das-licencas-maternidade-e-paternidade-ganha-apoio-no-senado
# ✅ Texto extraído (445 palavras) - https://www.camara.leg.br/noticias/1181501-comissao-aprova-projeto-que-obriga-sus-a-realizar-tratamento-de-implante-dentario/
# ✅ Texto extraído (305 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/18/projeto-assegura-a-medicos-inviolabilidade-de-consultorios-arquivos-e-comunicacoes
# ✅ Texto extraído (697 palavras) - https://www.camara.leg.br/noticias/1181509-comissao-aprova-classificacao-da-espinha-bifida-como-deficiencia-legal/
# ✅ Texto extraído (152 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/ifi-preve-r-10-bilhoes-a-mais-com-iof-em-2025
# ✅ Texto extraído (155 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/definidos-senadores-que-vao-aos-eua-dialogar-sobre-tarifas
# ✅ Texto extraído (587 palavras) - https://www.camara.leg.br/noticias/1181545-comissao-aprova-centros-psicopedagogicos-para-criancas-com-altas-habilidades-no-sus/
# ✅ Texto extraído (143 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/senado-faz-homenagem-postuma-ao-fundador-da-igreja-crista-maranata
# ✅ Texto extraído (923 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/sessao-lembra-trabalho-de-evangelizacao-do-fundador-da-igreja-crista-maranata
# ✅ Texto extraído (1021 palavras) - https://www.camara.leg.br/noticias/1181609-para-especialistas-prevencao-de-quedas-entre-idosos-depende-de-politicas-publicas-integradas/
# ✅ Texto extraído (633 palavras) - https://www.camara.leg.br/noticias/1181476-comissao-aprova-projeto-que-proibe-qualquer-caso-de-casamento-antes-dos-16-anos/
# ✅ Texto extraído (584 palavras) - https://www.camara.leg.br/noticias/1181450-comissao-aprova-oferta-de-educacao-especial-ao-aluno-com-deficiencia-que-apresente-laudo-medico/
# ✅ Texto extraído (468 palavras) - https://www.camara.leg.br/noticias/1181433-comissao-aprova-regra-para-facilitar-identificacao-de-precos-de-produtos-por-idosos/
# ✅ Texto extraído (77 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/ifi-aponta-cenario-mais-favoravel-ao-cumprimento-da-meta-fiscal
# ✅ Texto extraído (365 palavras) - https://www.camara.leg.br/noticias/1181424-comissao-aprova-exigencia-de-informacoes-sobre-calibragem-em-aparelhos-de-radioterapia/
# ✅ Texto extraído (688 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/meio-ambiente-e-sustentabilidade-o-que-foi-aprovado-no-primeiro-semestre
# ✅ Texto extraído (821 palavras) - https://www.camara.leg.br/noticias/1181547-comissao-aprova-criacao-de-programa-para-ajudar-pessoas-com-vicio-em-jogos-de-azar/
# ✅ Texto extraído (211 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/governo-libera-r-3-3bi-para-ressarcir-aposentados-e-sanciona-rotas-turisticas
# ✅ Texto extraído (231 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/sancionada-a-rota-turistica-imperial-caminho-dos-principes-em-santa-catarina
# ✅ Texto extraído (98 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/manoel-mattos-pode-entrar-para-o-livro-dos-herois-da-patria
# ✅ Texto extraído (555 palavras) - https://www.camara.leg.br/noticias/1181457-comissao-aprova-projeto-que-suspende-regulamentacao-da-lei-da-mata-atlantica/
# ✅ Texto extraído (69 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-de-esporte-vai-debater-formacao-de-atletas-nas-forcas-armadas
# ✅ Texto extraído (755 palavras) - https://www.camara.leg.br/noticias/1181469-especialistas-em-cancer-de-cabeca-e-pescoco-ressaltam-necessidade-de-avanco-no-diagnostico-precoce/
# ✅ Texto extraído (513 palavras) - https://www.camara.leg.br/noticias/1181474-comissao-aprova-proposta-de-areas-exclusivas-para-veiculos-escolares-pararem-perto-de-escolas/
# ✅ Texto extraído (609 palavras) - https://www.camara.leg.br/noticias/1181417-comissao-aprova-projeto-que-obriga-plataformas-digitais-a-alertar-sobre-vicio-em-pornografia/
# ✅ Texto extraído (64 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/aprovado-projeto-que-cria-o-dia-nacional-do-cidadao-solidario
# ✅ Texto extraído (234 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/criada-rota-turistica-costa-azul-em-santa-catarina
# ✅ Texto extraído (80 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/ccj-deve-votar-em-agosto-suspensao-de-limite-para-pesca-da-tainha-em-sc
# ✅ Texto extraído (78 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/ccj-vai-analisar-pena-maior-para-quem-fornece-drogas-a-menores
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1181353-comissao-aprova-ampliacao-da-cota-para-pessoas-com-deficiencia-em-instituicoes-federais-de-ensino/
# ✅ Texto extraído (73 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/fraudes-financeiras-contra-idosos-devem-mobilizar-senadores-no-segundo-semestre
# ✅ Texto extraído (221 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/girao-comemora-veto-de-lula-ao-aumento-do-numero-de-deputados
# ✅ Texto extraído (538 palavras) - https://www.camara.leg.br/noticias/1181310-comissao-aprova-projeto-que-destina-01-da-arrecadacao-de-apostas-esportivas-para-esportes-de-surdos/
# ✅ Texto extraído (446 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/definidos-senadores-da-comissao-externa-que-vai-aos-eua-negociar-tarifas
# ✅ Texto extraído (97 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senado-aprova-pec-que-exclui-precatorios-da-meta-fiscal
# ✅ Texto extraído (534 palavras) - https://www.camara.leg.br/noticias/1181298-comissao-aprova-selo-de-boas-praticas-de-acessibilidade-para-empresas/
# ✅ Texto extraído (374 palavras) - https://www.camara.leg.br/noticias/1181299-projeto-abre-credito-suplementar-de-r-215-bilhoes-no-orcamento-de-2025-para-atender-fundos-regionais/
# ✅ Texto extraído (567 palavras) - https://www.camara.leg.br/noticias/1181279-lula-veta-projeto-que-aumenta-de-513-para-531-o-numero-de-deputados-federais/
# ✅ Texto extraído (436 palavras) - https://www.camara.leg.br/noticias/1181328-hugo-motta-cria-programa-camara-pelo-brasil-para-ampliar-o-dialogo-com-a-sociedade/
# ✅ Texto extraído (480 palavras) - https://www.camara.leg.br/noticias/1181314-medida-provisoria-abre-credito-de-r-33-bilhoes-para-ressarcir-aposentados-e-pensionistas/
# ✅ Texto extraído (511 palavras) - https://www.camara.leg.br/noticias/1181268-comissao-aprova-proibicao-de-abastecimento-de-veiculos-apos-disparo-de-trava-de-seguranca-da-bomba/
# ✅ Texto extraído (180 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/decisao-sobre-fiscalizacao-dos-correios-e-adiada-apos-pedido-de-vista
# ✅ Texto extraído (620 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/ifi-desempenho-fiscal-melhora-no-semestre-mas-cenario-de-2026-preocupa
# ✅ Texto extraído (315 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/girao-denuncia-prova-manipulada-pela-pgr-para-condenar-torres
# ✅ Texto extraído (2503 palavras) - https://www.camara.leg.br/noticias/1181221-parlamentares-e-representantes-do-setor-esportivo-criticam-vetos-a-lei-geral-do-esporte/
# ✅ Texto extraído (61 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/veto-de-lula-ao-aumento-do-numero-de-deputados-divide-opinioes-no-senado
# ✅ Texto extraído (440 palavras) - https://www.camara.leg.br/noticias/1153702-projeto-inclui-materia-sobre-autismo-na-formacao-de-professores-de-ensino-basico/
# ✅ Texto extraído (244 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/dra-eudocia-destaca-lei-para-prevencao-de-partos-prematuros
# ✅ Texto extraído (405 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/fraudes-no-inss-medida-provisoria-libera-r-3-3-bi-para-ressarcimento-de-vitimas
# ✅ Texto extraído (704 palavras) - https://www.camara.leg.br/noticias/1181234-comissao-aprova-projeto-que-preve-medidas-para-seguranca-de-usuarios-em-aplicativos-de-relacionamento/
# ✅ Texto extraído (768 palavras) - https://www.camara.leg.br/noticias/1181206-comissao-rejeita-projeto-que-proibe-marcacao-de-animais-com-ferro-quente/
# ✅ Texto extraído (277 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/comissao-quer-auditoria-do-tcu-em-agencias-reguladoras-e-programa-cisternas
# ✅ Texto extraído (456 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/17/lula-veta-aumento-do-numero-de-deputados-federais
# ✅ Texto extraído (575 palavras) - https://www.camara.leg.br/noticias/1181218-comissao-aprova-projeto-que-preve-compensacao-ao-consumidor-pela-interrupcao-de-servicos-continuos/
# ✅ Texto extraído (188 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/projeto-que-oficializa-o-nome-da-lei-maria-da-penha-segue-para-o-plenario
# ✅ Texto extraído (142 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/decisao-de-moraes-que-valida-aumento-do-iof-repercute-no-senado
# ✅ Texto extraído (176 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/plenario-aprova-reajuste-concedido-pelo-governo-a-militares
# ✅ Texto extraído (178 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/senado-aprova-pec-dos-precatorios-em-primeiro-turno
# ✅ Texto extraído (138 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/senado-aprova-proposta-que-amplia-incentivos-fiscais-ao-esporte
# ✅ Texto extraído (2362 palavras) - https://www.camara.leg.br/noticias/1181191-saiba-mais-sobre-o-projeto-que-altera-o-licenciamento-ambiental/
# ✅ Texto extraído (1229 palavras) - https://www.camara.leg.br/noticias/1181186-deputados-manifestam-se-a-favor-e-contra-o-projeto-sobre-licenciamento-ambiental/
# ✅ Texto extraído (3019 palavras) - https://www.camara.leg.br/noticias/1181164-camara-aprova-projeto-que-altera-regras-de-licenciamento-ambiental/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1181158-deputados-analisam-projeto-que-altera-regras-de-licenciamento-ambiental-acompanhe/
# ✅ Texto extraído (1284 palavras) - https://www.camara.leg.br/noticias/1181146-camara-aprova-projeto-que-facilita-acesso-do-agricultor-familiar-ao-beneficio-garantia-safra/
# ✅ Texto extraído (953 palavras) - https://www.camara.leg.br/noticias/1181135-camara-aprova-projeto-que-atribui-a-caixa-assumir-indenizacoes-de-seguros-antigos-de-habitacao/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1181124-camara-aprova-uso-de-fundo-social-para-agricultores-atingidos-por-calamidades/
# ✅ Texto extraído (81 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/congresso-aprova-reajuste-para-forcas-armadas
# ✅ Texto extraído (2336 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/senado-aprova-em-primeiro-turno-nova-regra-para-precatorios
# ✅ Texto extraído (317 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/heinze-pede-alivio-da-divida-agricola-no-rs
# ✅ Texto extraído (64 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/senado-celebrara-programa-calha-norte-e-dia-do-advogado
# ✅ Texto extraído (310 palavras) - https://www.camara.leg.br/noticias/1181111-deputados-analisam-uso-de-fundo-social-para-agricultores-atingidos-por-calamidades-acompanhe/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1181081-camara-aprova-projeto-que-cria-fundo-de-financiamento-para-o-ministerio-publico-da-uniao/
# ✅ Texto extraído (670 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/decisao-monocratica-de-alexandre-de-moraes-sobre-decreto-do-iof-repercute-no-senado
# ✅ Texto extraído (189 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/senado-aprova-reajuste-para-forcas-armadas
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/16/aumento-dos-militares
# ✅ Texto extraído (73 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senado-aprova-politica-para-prevenir-partos-prematuros-e-apoiar-maes-e-bebes
# ✅ Texto extraído (715 palavras) - https://www.camara.leg.br/noticias/1181044-deputados-e-especialistas-afirmam-que-criminalizacao-da-cultura-negra-e-um-fenomeno-historico/
# ✅ Texto extraído (1157 palavras) - https://www.camara.leg.br/noticias/1181088-deputados-comentam-decisao-de-moraes-de-validar-maior-parte-do-decreto-sobre-iof/
# ✅ Texto extraído (285 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/rodrigues-comemora-projeto-que-amplia-e-torna-permanentes-incentivos-do-esporte
# ✅ Texto extraído (206 palavras) - https://www.camara.leg.br/noticias/1181028-deputados-analisam-projeto-que-cria-fundo-de-financiamento-para-o-ministerio-publico-da-uniao-acompanhe/
# ✅ Texto extraído (451 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/aprovado-projeto-que-aumenta-incentivos-fiscais-ao-esporte-vai-a-sancao
# ✅ Texto extraído (659 palavras) - https://www.camara.leg.br/noticias/1180816-comissao-aprova-equiparacao-da-distonia-a-deficiencia-para-efeitos-legais/
# ✅ Texto extraído (1396 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/familiares-defendem-presos-do-8-de-janeiro-e-apontam-violacoes
# ✅ Texto extraído (285 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/jayme-campos-critica-tarifa-dos-eua-e-cobra-resposta-diplomatica-do-brasil
# ✅ Texto extraído (83 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/plenario-decide-que-lei-de-incentivo-ao-esporte-vai-ser-permanente
# ✅ Texto extraído (649 palavras) - https://www.camara.leg.br/noticias/1181031-camara-decide-que-projeto-sobre-crimes-de-trabalho-escravo-sera-votado-em-plenario/
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/16/esporte
# ✅ Texto extraído (359 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/izalci-critica-postura-de-lula-nas-relacoes-com-os-eua
# ✅ Texto extraído (473 palavras) - https://www.camara.leg.br/noticias/1180856-comissao-aprova-projeto-que-garante-a-aluno-autista-o-direito-a-material-didatico-complementar/
# ✅ Texto extraído (297 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/nelsinho-trad-propoe-dialogo-com-os-eua-para-superar-crise-comercial
# ✅ Texto extraído (213 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/wellington-fagundes-defende-pec-que-parcela-divida-de-municipios
# ✅ Texto extraído (817 palavras) - https://www.camara.leg.br/noticias/1180791-comissao-aprova-auxilio-financeiro-para-cuidador-familiar-de-idoso-ou-pessoa-com-deficiencia/
# ✅ Texto extraído (476 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/cdh-apresenta-balanco-do-primeiro-semestre-deste-ano
# ✅ Texto extraído (182 palavras) - https://www.camara.leg.br/noticias/1181015-deputados-analisam-pedido-de-votacao-em-plenario-de-projeto-sobre-crimes-de-trabalho-escravo-acompanhe/
# ✅ Texto extraído (515 palavras) - https://www.camara.leg.br/noticias/1180797-comissao-aprova-obrigacao-do-sus-oferecer-cirurgia-fetal-para-tratar-malformacao-na-coluna-vertebral/
# ✅ Texto extraído (1517 palavras) - https://www.camara.leg.br/noticias/1180972-cop30-podera-ter-espaco-formal-para-participacao-de-parlamentares/
# ✅ Texto extraído (302 palavras) - https://www.camara.leg.br/noticias/1180978-camara-aprova-regime-de-urgencia-para-cinco-projetos-de-lei/
# ✅ Texto extraído (480 palavras) - https://www.camara.leg.br/noticias/1180999-motta-cria-comissao-especial-para-analisar-pec-da-seguranca-publica/
# ✅ Texto extraído (57 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-adia-decisao-sobre-investigacao-de-irregularidades-nos-correios
# ✅ Texto extraído (67 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-aprova-obrigatoriedade-de-eleicoes-nos-conselhos-tutelares
# ✅ Texto extraído (302 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/confucio-moura-relata-visita-a-comunidades-ribeirinhas-e-indigenas
# ✅ Texto extraído (212 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/cleitinho-critica-tarifaco-anunciado-por-donald-trump
# ✅ Texto extraído (155 palavras) - https://www.camara.leg.br/noticias/1180636-deputados-analisam-pedidos-de-urgencia-para-projetos-de-lei-acompanhe/
# ✅ Texto extraído (92 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/vetos-prejudicaram-a-lei-geral-do-esporte-e-precisam-ser-revistos-aponta-debate
# ✅ Texto extraído (649 palavras) - https://www.camara.leg.br/noticias/1180870-comissao-aprova-obrigatoriedade-de-autorizacao-judicial-para-menor-atuar-como-influenciador-digital/
# ✅ Texto extraído (249 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/paulo-paim-agradece-reconhecimento-pelo-diap-de-sua-trajetoria-parlamentar
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1173927-projeto-torna-obrigatoria-autorizacao-judicial-previa-para-menor-atuar-como-influenciador-digital/
# ✅ Texto extraído (77 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-de-seguranca-debate-igualdade-salarial-entre-forcas-do-df
# ✅ Texto extraído (221 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/esperidiao-amin-critica-denuncia-da-pgr-contra-bolsonaro
# ✅ Texto extraído (647 palavras) - https://www.camara.leg.br/noticias/1180693-comissao-aprova-proibicao-de-custodia-de-presos-em-hospitais-por-policiais-militares/
# ✅ Texto extraído (547 palavras) - https://www.camara.leg.br/noticias/1180807-comissao-aprova-diagnostico-e-tratamento-de-trombofilias-pelo-sus/
# ✅ Texto extraído (1222 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/cesp-representantes-do-setor-esportivo-criticam-vetos-a-lei-geral-do-esporte
# ✅ Texto extraído (311 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/subcomissao-aprova-debate-sobre-embargos-do-ibama
# ✅ Texto extraído (79 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/dia-de-protecao-as-florestas-sera-comemorado-nesta-sexta
# ✅ Texto extraído (142 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/forcas-de-seguranca-defendem-pec-sobre-correcao-do-fundo-constitucional-do-df
# ✅ Texto extraído (68 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/executivo-e-congresso-reagem-a-tarifa-dos-eua-e-falam-em-2018agressao-ao-brasil2019
# ✅ Texto extraído (826 palavras) - https://www.camara.leg.br/noticias/1180618-comissao-aprova-garantia-de-atendimento-prioritario-no-sus-para-pacientes-com-endometriose/
# ✅ Texto extraído (500 palavras) - https://www.camara.leg.br/noticias/1180833-comissao-aprova-gratuidade-do-georreferenciamento-em-areas-destinadas-a-reforma-agraria/
# ✅ Texto extraído (81 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/compra-publica-deve-priorizar-veiculos-e-combustiveis-menos-poluentes-aprova-ci
# ✅ Texto extraído (341 palavras) - https://www.camara.leg.br/noticias/1180602-comissao-aprova-projeto-que-garante-continuidade-de-atendimento-para-gestantes-em-planos-de-saude/
# ✅ Texto extraído (815 palavras) - https://www.camara.leg.br/noticias/1180649-comissao-aprova-campanhas-educativas-permanentes-do-governo-sobre-violencia-domestica/
# ✅ Texto extraído (462 palavras) - https://www.camara.leg.br/noticias/1180597-comissao-aprova-publicacao-a-cada-dois-anos-de-relatorio-sobre-violencia-contra-as-mulheres/
# ✅ Texto extraído (707 palavras) - https://www.camara.leg.br/noticias/1180749-comissao-aprova-oferta-de-curso-de-libras-em-universidades-para-familias-de-criancas-com-deficiencia-auditiva/
# ✅ Texto extraído (1273 palavras) - https://www.camara.leg.br/noticias/1180848-comissao-da-camara-aprova-projeto-que-isenta-de-imposto-de-renda-quem-ganha-ate-r-5-mil-mensais/
# ✅ Texto extraído (534 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/pedido-de-vista-adia-votacao-de-projetos-sobre-exploracao-em-terras-indigenas
# ✅ Texto extraído (661 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/debatedores-defendem-pec-que-blinda-fundo-constitucional-do-df-contra-cortes
# ✅ Texto extraído (472 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/vai-ao-plenario-projeto-que-oficializa-nome-da-lei-maria-da-penha
# ✅ Texto extraído (373 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/cdh-aumenta-pena-para-quem-fornece-drogas-ou-bebidas-a-menores
# ✅ Texto extraído (54 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senado-aprova-missao-a-washington-para-negociar-tarifaco-de-donald-trump
# ✅ Texto extraído (443 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/cdh-torna-obrigatoria-eleicao-direta-para-conselhos-tutelares
# ✅ Texto extraído (314 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/damares-diz-que-justica-age-como-regime-autoritario-no-julgamento-de-bolsonaro
# ✅ Texto extraído (168 palavras) - https://www.camara.leg.br/noticias/1180759-profissionais-pedem-atualizacao-das-normas-em-terapias-nutricionais-assista/
# ✅ Texto extraído (378 palavras) - https://www.camara.leg.br/noticias/1180605-comissao-aprova-prioridade-para-gestantes-e-lactantes-no-acesso-a-vacina-e-medicamentos-durante-epidemias/
# ✅ Texto extraído (366 palavras) - https://www.camara.leg.br/noticias/1180747-tarifas-dos-eua-motta-diz-que-o-congresso-esta-pronto-para-agir-inclusive-durante-o-recesso/
# ✅ Texto extraído (550 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/em-balanco-da-cra-zequinha-destaca-projetos-que-beneficiam-agricultores
# ✅ Texto extraído (56 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/marcelo-castro-detalha-proposta-do-novo-codigo-eleitoral-no-senado
# ✅ Texto extraído (459 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/obra-do-senado-e-semifinalista-do-premio-jabuti-academico-2025
# ✅ Texto extraído (443 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/davi-diz-que-congresso-e-governo-atuarao-juntos-em-reacao-a-tarifaco-dos-eua
# ✅ Texto extraído (706 palavras) - https://www.camara.leg.br/noticias/1180586-comissao-aprova-projeto-que-proibe-escolas-de-promover-alunos-que-nao-tem-nota-para-passar-de-ano/
# ✅ Texto extraído (1222 palavras) - https://www.camara.leg.br/noticias/1180595-projeto-preve-regras-para-protecao-de-criancas-e-adolescentes-em-ambientes-digitais/
# ✅ Texto extraído (480 palavras) - https://www.camara.leg.br/noticias/1179428-comissao-debate-regras-para-contratacao-temporaria-de-trabalhadores-rurais/
# ✅ Texto extraído (185 palavras) - https://www.camara.leg.br/noticias/1180626-motta-e-agraciado-com-a-medalha-merito-santos-dumont/
# ✅ Texto extraído (301 palavras) - https://www.camara.leg.br/noticias/1179411-camara-cancela-debate-sobre-securitizacao-de-dividas-rurais/
# ✅ Texto extraído (332 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/zequinha-quer-proibir-repasse-do-custo-do-furto-de-energia-aos-consumidores
# ✅ Texto extraído (272 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/isencao-de-taxa-de-navegacao-de-cargas-no-norte-e-nordeste-segue-para-sancao
# ✅ Texto extraído (651 palavras) - https://www.camara.leg.br/noticias/1180601-para-motta-atual-momento-e-de-unidade-nacional-para-proteger-o-pais/
# ✅ Texto extraído (208 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/vai-a-camara-projeto-que-torna-fortaleza-a-capital-nacional-do-pao
# ✅ Texto extraído (481 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/boa-vista-deve-ganhar-titulo-de-capital-da-pacoca-de-carne-com-farinha
# ✅ Texto extraído (435 palavras) - https://www.camara.leg.br/noticias/1179457-cancelado-debate-sobre-inclusao-de-pessoas-autistas-no-mercado-de-trabalho/
# ✅ Texto extraído (1648 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/nova-regra-para-pagamento-de-precatorios-volta-a-analise-do-senado
# ✅ Texto extraído (423 palavras) - https://www.camara.leg.br/noticias/1180555-camara-dos-deputados-pode-votar-hoje-regras-para-renovacao-de-beneficios-tributarios/
# ✅ Texto extraído (387 palavras) - https://www.camara.leg.br/noticias/1179346-comissoes-de-esporte-da-camara-e-do-senado-debatem-vetos-a-lei-geral-do-esporte/
# ✅ Texto extraído (417 palavras) - https://www.camara.leg.br/noticias/1179348-camara-cancela-debate-sobre-mecanismos-de-fortalecimento-das-agencias-reguladoras/
# ✅ Texto extraído (377 palavras) - https://www.camara.leg.br/noticias/1179392-comissao-do-imposto-de-renda-debate-parecer-do-relator-nesta-quarta-feira/
# ✅ Texto extraído (260 palavras) - https://www.camara.leg.br/noticias/1179445-cancelado-debate-sobre-medidas-de-protecao-aos-idosos-diante-do-superendividamento/
# ✅ Texto extraído (360 palavras) - https://www.camara.leg.br/noticias/1179370-camara-dos-deputados-discute-preparativos-para-a-cop30-e-desafios-ambientais/
# ✅ Texto extraído (264 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/16/projeto-isenta-custos-processuais-para-criancas-e-jovens-com-deficiencias-e-doencas-graves
# ✅ Texto extraído (1291 palavras) - https://www.camara.leg.br/noticias/1180508-camara-aprova-projeto-que-aperfeicoa-sistema-de-alerta-sobre-desaparecimento-de-crianca-idoso-ou-pessoa-com-deficiencia/
# ✅ Texto extraído (373 palavras) - https://www.camara.leg.br/noticias/1180490-motta-espera-votacao-rapida-no-senado-da-proposta-que-altera-regras-sobre-precatorios/
# ✅ Texto extraído (596 palavras) - https://www.camara.leg.br/noticias/1180479-camara-aprova-novas-regras-para-beneficio-fiscal-aos-portos-das-regioes-norte-e-nordeste/
# ✅ Texto extraído (236 palavras) - https://www.camara.leg.br/noticias/1180486-camara-aprova-regime-de-urgencia-para-tres-projetos/
# ✅ Texto extraído (3297 palavras) - https://www.camara.leg.br/noticias/1180446-camara-aprova-em-2o-turno-pec-que-altera-regras-para-pagamento-de-precatorios/
# ✅ Texto extraído (861 palavras) - https://www.camara.leg.br/noticias/1180424-relator-da-reforma-administrativa-adianta-pontos-das-propostas-que-pretende-apresentar-depois-do-recesso/
# ✅ Texto extraído (1946 palavras) - https://www.camara.leg.br/noticias/1180381-aprovada-em-1o-turno-pec-que-altera-regras-para-pagamento-de-precatorios/
# ✅ Texto extraído (260 palavras) - https://www.camara.leg.br/noticias/1180418-motta-cancela-reunioes-das-comissoes-permanentes-para-facilitar-votacoes-no-plenario/
# ✅ Texto extraído (477 palavras) - https://www.camara.leg.br/noticias/1179676-comissao-aprova-assistencia-a-saude-ocular-para-criancas-em-municipios-com-menos-de-50-mil-habitantes/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1180262-comissao-aprova-auxilio-financeiro-e-psicologico-a-maes-de-pessoa-com-deficiencia-ou-autismo/
# ✅ Texto extraído (453 palavras) - https://www.camara.leg.br/noticias/1180409-corregedoria-notifica-deputados-sobre-processo-de-recontagem-de-votos/
# ✅ Texto extraído (130 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/iof-audiencia-de-conciliacao-no-stf-termina-sem-acordo
# ✅ Texto extraído (72 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-vai-a-belem-acompanhar-preparativos-para-cop-30
# ✅ Texto extraído (123 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/debate-evidencia-controversia-sobre-atividades-economicas-em-terras-indigenas
# ✅ Texto extraído (79 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/aprovado-projeto-que-transforma-cargos-da-justica-federal-no-piaui
# ✅ Texto extraído (254 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/pedro-chaves-defende-projeto-que-facilita-adesao-de-estados-ao-propag
# ✅ Texto extraído (73 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-da-mp-que-tributa-aplicacoes-financeiras-e-bets-ja-tem-plano-de-trabalho
# ✅ Texto extraído (586 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/relatorio-preliminar-da-ldo-2026-e-aprovado-na-comissao-mista-de-orcamento
# ✅ Texto extraído (63 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/governo-regulamenta-lei-da-reciprocidade-economica
# ✅ Texto extraído (67 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/comissao-aprova-regras-de-seguranca-para-doacao-de-alimentos
# ✅ Texto extraído (61 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senado-libera-beneficio-garantia-safra-para-produtores-do-seminarido-no-rj
# ✅ Texto extraído (1702 palavras) - https://www.camara.leg.br/noticias/1180335-comissao-de-constituicao-e-justica-aprova-admissibilidade-da-pec-da-seguranca-publica/
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1180302-comissao-aprova-extensao-das-regras-da-lei-dos-agentes-de-saude-para-outros-agentes/
# ✅ Texto extraído (56 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/damares-e-necessario-atualizar-o-estatuto-de-crianca-e-do-adolescente
# ✅ Texto extraído (351 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/sem-acordo-entre-governo-e-congresso-decisao-sobre-o-iof-fica-para-o-supremo
# ✅ Texto extraído (333 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/ce-aprova-nome-de-manoel-mattos-no-livro-dos-herois-da-patria
# ✅ Texto extraído (343 palavras) - https://www.camara.leg.br/noticias/1180201-camara-analisa-pec-que-altera-regras-para-pagamento-de-precatorios-acompanhe/
# ✅ Texto extraído (306 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/pacheco-destaca-liberacao-de-emprestimo-de-us-200-milhoes-para-minas-gerais
# ✅ Texto extraído (68 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/fp-em-defesa-da-exploracao-de-petroleo-na-margem-equatorial-aprova-plano
# ✅ Texto extraído (68 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/sistema-brasileiro-de-apoio-oficial-ao-credito-a-exportacao-segue-para-camara
# ✅ Texto extraído (83 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/plenario-autoriza-acordo-com-polonia-para-evitar-dupla-tributacao-sobre-renda
# ✅ Texto extraído (162 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/senado-vai-celebrar-a-industria-hoteleira-e-dias-do-nutricionista-e-do-administrador
# ✅ Texto extraído (428 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/jovens-deixam-de-entrar-na-faculdade-por-causa-das-bets-aponta-girao
# ✅ Texto extraído (214 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/grupo-de-senadores-vai-aos-eua-negociar-tarifaco-de-trump
# ✅ Texto extraído (272 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/ce-aprova-projeto-que-considera-angelim-pe-a-capital-nordestina-do-cuscuz
# ✅ Texto extraído (278 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/aprovado-acordo-com-a-polonia-para-evitar-bitributacao
# ✅ Texto extraído (321 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/humberto-diz-que-pais-caminha-para-punir-atos-golpitas
# ✅ Texto extraído (269 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/vai-a-camara-projeto-de-conscientizacao-sobre-deducoes-de-doacoes-no-ir
# ✅ Texto extraído (1147 palavras) - https://www.camara.leg.br/noticias/1180175-comissao-especial-aprova-parecer-sobre-proposta-que-permite-renegociar-precatorios/
# ✅ Texto extraído (347 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/senado-autoriza-emprestimos-de-us-450-milhoes-pela-bahia-junto-ao-bird
# ✅ Texto extraído (723 palavras) - https://www.camara.leg.br/noticias/1180307-governo-e-congresso-nao-chegam-a-acordo-sobre-aumento-do-iof-decisao-fica-para-o-stf/
# ✅ Texto extraído (69 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/mp-que-cria-programa-para-agilizar-trabalho-do-inss-passa-em-comissao
# ✅ Texto extraído (1002 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/atividade-economica-em-terras-indigenas-divide-opinioes-em-audiencia-na-cdh
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1180284-frentes-parlamentares-lancam-manifesto-pelo-adiamento-da-votacao-do-novo-licenciamento-ambiental/
# ✅ Texto extraído (281 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/ci-vai-investigar-paralisacao-de-obras-no-viaduto-da-br-364
# ✅ Texto extraído (58 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senadores-debatem-estrategias-do-brasil-para-tarifaco-de-trump
# ✅ Texto extraído (1154 palavras) - https://www.camara.leg.br/noticias/1180258-comissao-mista-de-orcamento-aprova-relatorio-preliminar-da-ldo-de-2026/
# ✅ Texto extraído (226 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/comissao-reconhece-a-guitarrada-como-manifestacao-da-cultura-nacional
# ✅ Texto extraído (327 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/vai-a-sancao-ampliacao-do-garantia-safra-para-regiao-do-semiarido-do-rio-de-janeiro
# ✅ Texto extraído (233 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/ce-reconhece-danca-de-sao-goncalo-como-manifestacao-da-cultura-nacional
# ✅ Texto extraído (277 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/vai-a-sancao-criacao-de-vara-para-julgar-recursos-da-justica-federal-no-piaui
# ✅ Texto extraído (648 palavras) - https://www.camara.leg.br/noticias/1179710-comissao-aprova-cobertura-obrigatoria-de-tratamento-de-saude-mental-completo-pelos-planos-de-saude/
# ✅ Texto extraído (254 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/cleitinho-defende-bolsonaro-e-questiona-pedido-de-condenacao
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/15/acordo-com-a-polonia
# ✅ Texto extraído (279 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/izalci-lucas-critica-mp-que-amplia-tributacao-sobre-fundos-e-apostas-on-line
# ✅ Texto extraído (337 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/esperidiao-amin-critica-tarifa-dos-eua-e-diz-que-o-cenario-e-ruim-para-todos
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/15/ampliacao-do-semiarido
# ✅ Texto extraído (223 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/pec-que-inclui-policia-cientifica-na-seguranca-publica-passa-pela-3a-discussao
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/15/justica-federal
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1180208-camara-celebra-35-anos-do-estatuto-da-crianca-e-do-adolescente/
# ✅ Texto extraído (496 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/renan-vai-presidir-comissao-de-mp-que-tributa-investimentos-e-apostas
# ✅ Texto extraído (266 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/comissao-mista-aprova-mp-que-cria-programa-para-agilizar-trabalho-do-inss
# ✅ Texto extraído (250 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/chico-rodrigues-cobra-acao-do-estado-para-impedir-queda-de-cobertura-vacinal
# ✅ Texto extraído (310 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/teresa-leitao-defende-reintegracao-de-concursados-demitidos-da-eletrobras
# ✅ Texto extraído (317 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/ci-aprova-preferencia-em-licitacoes-para-bens-e-servicos-sustentaveis
# ✅ Texto extraído (1454 palavras) - https://www.camara.leg.br/noticias/1180085-lei-que-amplia-destinacao-do-fundo-social-do-pre-sal-e-sancionada-com-vetos/
# ✅ Texto extraído (869 palavras) - https://www.camara.leg.br/noticias/1180219-deputado-andre-janones-esta-suspenso-do-mandato-por-tres-meses-por-ofender-colega-no-plenario/
# ✅ Texto extraído (453 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/vai-a-ccj-direito-de-taxistas-transferirem-autorizacao-para-explorar-o-servico
# ✅ Texto extraído (70 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senadores-criticam-tarifas-de-trump-e-pedem-cautela-com-projeto-sobre-exportacoes
# ✅ Texto extraído (75 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/autorizacoes-de-emprestimos-para-a-bahia-seguem-para-votacao-em-plenario
# ✅ Texto extraído (212 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/bittar-diz-que-rodrigo-constantino-e-perseguido-pelo-stf
# ✅ Texto extraído (919 palavras) - https://www.camara.leg.br/noticias/1179684-comissao-aprova-proposta-que-facilita-acesso-de-pessoa-com-deficiencia-a-politicas-publicas/
# ✅ Texto extraído (532 palavras) - https://www.camara.leg.br/noticias/1179387-cancelado-debate-sobre-o-impacto-de-tarifas-dos-eua-na-economia-brasileira/
# ✅ Texto extraído (865 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/cre-articula-missao-diplomatica-para-conter-tarifa-de-trump-contra-o-brasil
# ✅ Texto extraído (418 palavras) - https://www.camara.leg.br/noticias/1180051-medida-provisoria-extingue-cobranca-por-vistoria-de-taximetros/
# ✅ Texto extraído (652 palavras) - https://www.camara.leg.br/noticias/1180160-camara-lanca-concurso-de-video-pelo-fim-da-violencia-contra-a-mulher-veja-o-edital/
# ✅ Texto extraído (700 palavras) - https://www.camara.leg.br/noticias/1180020-comissao-aprova-novo-criterio-de-renda-para-a-solicitacao-de-beneficio-de-prestacao-continuada/
# ✅ Texto extraído (1865 palavras) - https://www.camara.leg.br/noticias/1180105-projeto-que-cria-sistema-nacional-de-educacao-divide-opinioes-em-debate-na-camara/
# ✅ Texto extraído (389 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/csp-aprova-indenizacao-para-familia-de-policiais-mortos-em-servico
# ✅ Texto extraído (542 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/na-cae-senadores-criticam-decisao-dos-eua-de-taxar-produtos-brasileiros-em-50
# ✅ Texto extraído (1094 palavras) - https://www.camara.leg.br/noticias/1180069-medida-provisoria-tenta-limitar-impacto-de-subsidios-ao-setor-energetico-na-conta-de-luz/
# ✅ Texto extraído (435 palavras) - https://www.camara.leg.br/noticias/1179990-comissao-aprova-preferencia-para-turismo-na-distribuicao-de-recursos-dos-fundos-constitucionais/
# ✅ Texto extraído (84 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/licenca-de-taxi-podera-ser-transferida-por-heranca-decide-comissao
# ✅ Texto extraído (59 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/petecao-ferrovia-transoceanica-promete-desenvolvimento-para-o-acre
# ✅ Texto extraído (98 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/csp-debate-pec-que-da-autonomia-ao-df-na-gestao-do-fundo-constitucional
# ✅ Texto extraído (403 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/cae-aprova-regras-para-doacao-de-alimentos-a-ongs
# ✅ Texto extraído (517 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/cae-autoriza-emprestimos-da-bahia-de-ate-us-450-milhoes-no-bird
# ✅ Texto extraído (730 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/mp-tenta-limitar-impacto-de-subsidios-ao-setor-energetico-na-conta-de-luz
# ✅ Texto extraído (565 palavras) - https://www.camara.leg.br/noticias/1179956-comissao-aprova-projeto-que-obriga-banco-a-informar-a-familia-sobre-saldo-em-conta-de-parente-falecido/
# ✅ Texto extraído (1443 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/sistema-de-apoio-ao-credito-a-exportacao-vai-a-camara
# ✅ Texto extraído (602 palavras) - https://www.camara.leg.br/noticias/1179948-comissao-aprova-criacao-de-documento-para-identificar-paciente-com-cancer/
# ✅ Texto extraído (406 palavras) - https://www.camara.leg.br/noticias/1179946-comissao-aprova-projeto-que-inclui-a-compra-de-tubulacao-de-esgoto-no-programa-minha-casa-minha-vida/
# ✅ Texto extraído (381 palavras) - https://www.camara.leg.br/noticias/1180036-seminario-na-camara-discute-como-prevenir-quedas-de-idosos-assista/
# ✅ Texto extraído (313 palavras) - https://www.camara.leg.br/noticias/1180016-seminario-na-camara-aponta-demora-no-tratamento-do-cancer-de-cabeca-e-pescoco-assista/
# ✅ Texto extraído (725 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/sancionada-com-vetos-lei-que-amplia-destinacao-do-fundo-social-do-pre-sal
# ✅ Texto extraído (677 palavras) - https://www.camara.leg.br/noticias/1179972-comissao-aprova-instalacao-obrigatoria-de-brinquedotecas-nas-delegacias-da-mulher/
# ✅ Texto extraído (610 palavras) - https://www.camara.leg.br/noticias/1179666-comissao-aprova-programa-de-protecao-a-grupos-vulneraveis-em-situacao-de-risco-e-desastres/
# ✅ Texto extraído (164 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/codigo-eleitoral-faz-60-anos-e-pode-passar-por-mudancas
# ✅ Texto extraído (223 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/medida-provisoria-extingue-cobranca-por-vistoria-de-taximetros
# ✅ Texto extraído (548 palavras) - https://www.camara.leg.br/noticias/1179958-deputados-podem-votar-hoje-o-projeto-que-muda-as-regras-do-licenciamento-ambiental/
# ✅ Texto extraído (476 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/15/projeto-preve-repouso-remunerado-para-pais-em-caso-de-aborto-espontaneo
# ✅ Texto extraído (168 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/margem-equatorial-governo-e-setor-petroleiro-cobram-urgencia-em-licenca
# ✅ Texto extraído (297 palavras) - https://www.camara.leg.br/noticias/1179181-comissao-debate-retomada-das-atividades-no-rio-grande-do-sul-apos-enchentes/
# ✅ Texto extraído (391 palavras) - https://www.camara.leg.br/noticias/1178530-comissao-debate-sustentabilidade-na-producao-e-na-comercializacao-de-cacau-e-chocolate/
# ✅ Texto extraído (494 palavras) - https://www.camara.leg.br/noticias/1178508-comissao-debate-implementacao-da-lei-que-instituiu-a-parentalidade-positiva/
# ✅ Texto extraído (339 palavras) - https://www.camara.leg.br/noticias/1178523-comissao-discute-transicao-demografica-e-envelhecimento-da-populacao-brasileira/
# ✅ Texto extraído (301 palavras) - https://www.camara.leg.br/noticias/1179331-conselho-de-etica-analisa-processo-contra-deputado-andre-janones/
# ✅ Texto extraído (433 palavras) - https://www.camara.leg.br/noticias/1178462-comissao-da-camara-debate-concessao-de-aposentadoria-especial-para-agentes-de-saude/
# ✅ Texto extraído (461 palavras) - https://www.camara.leg.br/noticias/1178446-parecer-com-novas-regras-para-pagamento-de-precatorios-pode-ser-votado-na-terca/
# ✅ Texto extraído (663 palavras) - https://www.camara.leg.br/noticias/1178456-comissao-debate-conscientizacao-diagnostico-e-tratamento-das-hepatites-virais/
# ✅ Texto extraído (329 palavras) - https://www.camara.leg.br/noticias/1178486-comissao-de-saude-debate-atualizacao-de-normas-para-terapia-nutricional/
# ✅ Texto extraído (740 palavras) - https://www.camara.leg.br/noticias/1179903-camara-aprova-ampliacao-de-atividades-que-poderao-ser-terceirizadas-nos-presidios/
# ✅ Texto extraído (997 palavras) - https://www.camara.leg.br/noticias/1179885-camara-aprova-novas-regras-para-liberacao-de-recursos-do-fundo-de-desenvolvimento-cientifico-e-tecnologico/
# ...
# ✅ Texto extraído (355 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/girao-denuncia-perseguicao-politica-em-cassacao-do-prefeito-de-juazeiro-do-norte
# ✅ Texto extraído (345 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/plenario-aprova-protocolo-da-oit-contra-trabalho-forcado-texto-vai-a-promulgacao
# ✅ Texto extraído (78 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/ccj-vai-analisar-ampliacao-da-legitima-defesa
# ✅ Texto extraído (142 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/aproveitamento-de-concurso-e-mudanca-em-cargos-do-stj-seguem-para-sancao
# ✅ Texto extraído (1345 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/mudancas-na-destinacao-do-fundo-social-seguem-para-a-sancao
# ✅ Texto extraído (120 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/apos-licenca-de-vanderlan-pedro-chaves-assume-vaga-pelo-estado-de-goias
# ✅ Texto extraído (283 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/aprovada-criacao-de-varas-federais-e-cargos-em-santa-catarina
# ✅ Texto extraído (549 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/senado-aprova-politica-para-manter-jovens-agricultores-no-campo
# ✅ Texto extraído (801 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/maes-vitimas-de-violencia-domestica-no-exterior-pedem-mudanca-na-legislacao
# ✅ Texto extraído (794 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/debate-aponta-que-sem-apoio-municipios-menores-nao-atingem-metas-de-saneamento
# ✅ Texto extraído (557 palavras) - https://www.camara.leg.br/noticias/1173260-projeto-cria-area-especial-de-interesse-turistico-em-minas-gerais/
# ✅ Texto extraído (1448 palavras) - https://www.camara.leg.br/noticias/1174791-especialistas-apostam-em-objetivo-do-pne-que-busca-reduzir-desigualdades-na-educacao-basica/
# ✅ Texto extraído (350 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/confucio-diz-que-divida-publica-ameaca-investimentos
# ✅ Texto extraído (91 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/senado-recebe-exposicao-de-200-anos-da-confederacao-do-equador
# ✅ Texto extraído (217 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/pec-da-educacao-como-vetor-de-progresso-passa-por-mais-uma-sessao-de-discussao
# ❌ Falha na extração - https://www12.senado.leg.br/noticias/senado-agora/2025/07/01/fundo-social-1
# ✅ Texto extraído (671 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/quarentena-para-ex-diretores-do-bc-gera-debate-no-plenario
# ❌ Falha na extração - https://www.camara.leg.br/noticias/1174694-camara-aprova-projeto-que-preve-calculo-do-valor-da-economia-do-cuidado-no-pais/
# ✅ Texto extraído (302 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/pedro-chaves-toma-posse-como-senador-por-goias
# ✅ Texto extraído (562 palavras) - https://www.camara.leg.br/noticias/1174603-comissao-aprova-criminalizacao-da-posse-de-celular-por-detento/
# ✅ Texto extraído (263 palavras) - https://www.camara.leg.br/noticias/1174450-entra-em-vigor-lei-que-isenta-cosmeticos-e-perfumes-artesanais-de-registro-na-anvisa/
# ✅ Texto extraído (602 palavras) - https://www.camara.leg.br/noticias/1174669-comissao-aprova-projeto-que-deixa-de-considerar-motim-o-descumprimento-de-ordem-superior-quando-for-ilegal/
# ✅ Texto extraído (354 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/kajuru-apresenta-projeto-para-combater-fraudes-em-descontos-de-aposentados
# ✅ Texto extraído (269 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/adiada-reuniao-da-comissao-da-mp-que-melhora-servicos-do-inss
# ✅ Texto extraído (85 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/especialistas-discutem-desafios-legislativos-para-a-exploracao-mineral
# ✅ Texto extraído (829 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/historiadores-destacam-meritos-da-confederacao-do-equador
# ✅ Texto extraído (196 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/augusta-apresenta-projetos-para-aumentar-controle-de-armas-e-proteger-as-mulheres
# ✅ Texto extraído (323 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/cra-pode-votar-compensacao-ambiental-em-dobro-e-combate-a-seca
# ✅ Texto extraído (440 palavras) - https://www.camara.leg.br/noticias/1174584-ccj-aprova-projeto-que-regulamenta-vistoria-em-imoveis-alugados/
# ✅ Texto extraído (82 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/brasil-deve-acelerar-politica-de-minerais-criticos-alertam-especialistas
# ✅ Texto extraído (241 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/lucas-barreto-critica-acao-do-mpf-contra-exploracao-de-petroleo-na-costa-do-amapa
# ✅ Texto extraído (299 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/styvenson-questiona-locacao-de-computadores-para-escolas-do-rn
# ✅ Texto extraído (582 palavras) - https://www.camara.leg.br/noticias/1174533-comissao-aprova-aumento-para-aquisicao-de-armas-de-fogo-e-municoes-por-policiais/
# ✅ Texto extraído (620 palavras) - https://www.camara.leg.br/noticias/1174654-representantes-de-carreiras-juridicas-pedem-mais-recursos-para-a-atuacao-dos-servidores/
# ✅ Texto extraído (471 palavras) - https://www.camara.leg.br/noticias/1174559-comissao-aprova-aumento-da-pena-de-trafico-de-drogas-quando-realizado-por-meio-de-drones/
# ✅ Texto extraído (1179 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/senado-entrega-primeira-edicao-da-comenda-chico-xavier-para-entidades-filantropicas
# ✅ Texto extraído (287 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/zequinha-marinho-destaca-qualificacao-de-mulheres-no-para
# ✅ Texto extraído (668 palavras) - https://www.camara.leg.br/noticias/1174667-lider-do-governo-diz-que-recurso-a-justica-sobre-iof-nao-e-confronto-com-o-congresso/
# ✅ Texto extraído (638 palavras) - https://www.camara.leg.br/noticias/1174579-ccj-aprova-garantia-de-aposentadoria-rural-para-mulheres-do-campo-identificadas-como-donas-de-casa/
# ✅ Texto extraído (633 palavras) - https://www.camara.leg.br/noticias/1174676-setor-produtivo-pede-ao-stf-que-mantenha-decisao-do-congresso-contra-aumento-do-iof/
# ✅ Texto extraído (82 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/cma-aprova-aumento-da-pena-para-crime-de-poluicao-de-ecossistemas
# ✅ Texto extraído (268 palavras) - https://www.camara.leg.br/noticias/1174599-deputados-analisam-projeto-que-preve-calculo-do-valor-da-economia-do-cuidado-no-pais-acompanhe/
# ✅ Texto extraído (269 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/damares-relata-casos-de-abuso-e-trafico-infantil-durante-missao-da-cdh-no-marajo
# ✅ Texto extraído (1425 palavras) - https://www.camara.leg.br/noticias/1174649-encontro-da-rede-legislativa-de-radio-e-tv-discute-programa-brasil-digital-e-a-chegada-da-tv-3-0/
# ✅ Texto extraído (940 palavras) - https://www.camara.leg.br/noticias/1174672-camara-aprova-mp-que-libera-r-520-milhoes-para-acoes-de-defesa-civil/
# ✅ Texto extraído (407 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/ccj-pode-votar-na-proxima-semana-fim-da-restricao-a-pesca-da-tainha-em-sc
# ✅ Texto extraído (203 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/adiada-votacao-de-incentivo-fiscal-para-exportacoes-de-micro-e-pequenas-empresas
# ✅ Texto extraído (283 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/projeto-que-aproveita-concurso-e-transforma-cargos-do-stj-vai-a-sancao
# ✅ Texto extraído (273 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/izalci-lucas-defende-educacao-como-politica-de-estado
# ✅ Texto extraído (619 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/cas-debate-criacao-da-rede-nacional-de-observatorios-da-mulher
# ✅ Texto extraído (1042 palavras) - https://www.camara.leg.br/noticias/1174527-especialistas-dizem-que-sistema-nacional-de-cultura-so-funcionara-com-fundo-de-financiamento/
# ✅ Texto extraído (1179 palavras) - https://www.camara.leg.br/noticias/1174607-decisao-do-governo-de-recorrer-contra-derrubada-de-aumento-do-iof-repercute-nos-discursos-de-deputados/
# ✅ Texto extraído (650 palavras) - https://www.camara.leg.br/noticias/1174550-ccj-aprova-licenca-maternidade-para-atletas-inclusive-em-caso-de-guarda-judicial-e-adocao/
# ✅ Texto extraído (117 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/brasil-nao-mapeou-seu-potencial-em-minerais-criticos-e-estrategicos-aponta-debate
# ✅ Texto extraído (88 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/ci-aprova-prestacao-de-contas-separada-para-royalties-do-petroleo
# ✅ Texto extraído (605 palavras) - https://www.camara.leg.br/noticias/1174535-ccj-aprova-regra-sobre-dissolucao-do-casamento-no-caso-de-morte-presumida-de-um-dos-conjuges/
# ✅ Texto extraído (654 palavras) - https://www.camara.leg.br/noticias/1174591-deputados-analisam-mp-que-libera-r-520-milhoes-para-acoes-de-defesa-civil-acompanhe/
# ✅ Texto extraído (169 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/cas-vai-remarcar-audiencia-sobre-venda-de-medicamentos-em-supermercados
# ✅ Texto extraído (274 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/ccj-aprova-projeto-que-aproveita-concurso-e-transforma-cargos-do-stj
# ✅ Texto extraído (231 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/plinio-valerio-denuncia-acoes-contra-produtores-rurais-no-amazonas
# ✅ Texto extraído (491 palavras) - https://www.camara.leg.br/noticias/1174546-fabio-schiochet-e-eleito-presidente-do-conselho-de-etica-e-defende-respeito-a-democracia/
# ✅ Texto extraído (87 palavras) - https://www12.senado.leg.br/noticias/audios/2025/07/debate-pede-gestao-compartilhada-no-combate-a-cercadinhos-em-praias
# ✅ Texto extraído (1257 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/debatedores-pedem-ajustes-no-projeto-de-acesso-as-praias-para-evitar-retrocesso
# ✅ Texto extraído (295 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/ccj-aprova-criacao-de-varas-federais-e-cargos-em-santa-catarina
# ✅ Texto extraído (453 palavras) - https://www.camara.leg.br/noticias/1174522-comissao-aprova-proposta-que-cria-categorias-de-pessoas-desaparecidas/
# ✅ Texto extraído (1340 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/debatedores-na-cae-defendem-mineracao-como-estrategia-para-energia-limpa
# ✅ Texto extraído (463 palavras) - https://www.camara.leg.br/noticias/1174504-comissao-aprova-proibicao-de-progressao-de-regime-para-reu-reincidente-em-crimes-dolosos/
# ✅ Texto extraído (925 palavras) - https://www.camara.leg.br/noticias/1174495-reforma-administrativa-academicos-sugerem-avaliacao-de-desempenho-de-servidores/
# ✅ Texto extraído (335 palavras) - https://www.camara.leg.br/noticias/1174174-proposta-permite-propaganda-eleitoral-em-duas-linguas/
# ✅ Texto extraído (319 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/ci-discutira-impacto-de-cortes-orcamentarios-em-agencias-reguladoras
# ✅ Texto extraído (555 palavras) - https://www.camara.leg.br/noticias/1174464-em-debate-governo-contesta-criticas-a-saude-financeira-das-empresas-estatais/
# ✅ Texto extraído (416 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/comissao-aprova-nova-hipotese-de-legitima-defesa-para-agentes-de-seguranca
# ✅ Texto extraído (852 palavras) - https://www.camara.leg.br/noticias/1174409-lei-incentiva-empreendedorismo-de-pessoas-com-deficiencia/
# ✅ Texto extraído (263 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/dados-sobre-crime-organizado-devem-integrar-sistema-nacional-de-seguranca
# ✅ Texto extraído (461 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/ci-projeto-exige-transparencia-no-uso-de-recursos-do-petroleo-e-da-mineracao
# ✅ Texto extraído (380 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/csp-amplia-legitima-defesa-em-casos-de-reacao-a-invasao-de-domicilio
# ✅ Texto extraído (739 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/aumento-de-penas-para-crimes-ligados-ao-garimpo-ilegal-passa-na-cma
# ✅ Texto extraído (148 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/lei-isenta-cosmeticos-e-perfumes-artesanais-de-registro-na-anvisa
# ✅ Texto extraído (382 palavras) - https://www.camara.leg.br/noticias/1157528-projeto-determina-que-3-das-emendas-impositivas-sejam-destinadas-ao-esporte/
# ✅ Texto extraído (386 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/criacao-de-frente-parlamentar-do-setor-nautico-segue-para-o-plenario
# ✅ Texto extraído (368 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/cma-aprova-aumento-de-pena-para-responsaveis-por-desastres-ambientais
# ✅ Texto extraído (441 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/lei-incentiva-empreendedorismo-de-pessoas-com-deficiencia
# ✅ Texto extraído (384 palavras) - https://www.camara.leg.br/noticias/1174029-cancelada-audiencia-com-a-ministra-simone-tebet-sobre-o-projeto-da-ldo-de-2026/
# ✅ Texto extraído (376 palavras) - https://www.camara.leg.br/noticias/1173676-comissao-debate-situacao-do-departamento-de-auditoria-do-sus/
# ✅ Texto extraído (173 palavras) - https://www12.senado.leg.br/noticias/videos/2025/07/codigo-eleitoral-marcelo-castro-propoe-regulacao-do-uso-de-ia-em-campanhas
# ✅ Texto extraído (349 palavras) - https://www12.senado.leg.br/noticias/materias/2025/07/01/projeto-cria-metas-de-desempenho-em-atendimento-de-pacientes-no-sus
# ✅ Texto extraído (314 palavras) - https://www.camara.leg.br/noticias/1173574-audiencia-na-camara-discute-a-politica-nacional-de-leitura-e-escrita/
# ✅ Texto extraído (241 palavras) - https://www.camara.leg.br/noticias/1174224-conselho-de-etica-da-camara-sera-instalado-e-elegera-novo-presidente-nesta-terca-feira/
# ✅ Texto extraído (450 palavras) - https://www.camara.leg.br/noticias/1173454-comissao-de-agricultura-debate-endividamento-de-produtores-rurais-de-mato-grosso-do-sul/
# ✅ Texto extraído (281 palavras) - https://www.camara.leg.br/noticias/1173443-comissao-especial-discute-financiamento-e-infraestrutura-da-educacao-basica/
# ✅ Texto extraído (489 palavras) - https://www.camara.leg.br/noticias/1173923-camara-pode-votar-nesta-terca-feira-mp-que-libera-r-520-milhoes-para-acoes-emergenciais-de-defesa-civil/
# ✅ Texto extraído (292 palavras) - https://www.camara.leg.br/noticias/1173404-comissao-debate-inclusao-de-diretrizes-para-uma-educacao-antirracista-no-novo-pne/
# ✅ Texto extraído (435 palavras) - https://www.camara.leg.br/noticias/1173590-grupo-de-trabalho-da-reforma-administrativa-ouve-especialistas-academicos-e-entidades-juridicas/
# ✅ Texto extraído (321 palavras) - https://www.camara.leg.br/noticias/1173452-comissao-avalia-acoes-do-governo-para-pessoas-com-deficiencia/
# ✅ Texto extraído (398 palavras) - https://www.camara.leg.br/noticias/1173398-comissao-de-defesa-dos-direitos-das-pessoas-com-deficiencia-debate-literatura-acessivel/
# ✅ Texto extraído (382 palavras) - https://www.camara.leg.br/noticias/1173357-comissao-de-meio-ambiente-debate-cooperativismo-e-sustentabilidade-em-audiencia-publica/
# ✅ Texto extraído (678 palavras) - https://www.camara.leg.br/noticias/1173370-comissao-debate-futuro-da-linha-ferrea-tronco-sul-em-santa-catarina/
# ✅ Texto extraído (415 palavras) - https://www.camara.leg.br/noticias/1173378-comissao-recebe-secretaria-do-governo-para-apresentacao-de-balanco-de-empresas-estatais/
# ✅ Texto extraído (302 palavras) - https://www.camara.leg.br/noticias/1173362-comissao-debate-repressao-no-campo-durante-a-ditadura-militar/
# ✅ Texto extraído (362 palavras) - https://www.camara.leg.br/noticias/1173355-comissao-de-cultura-debate-a-regulamentacao-do-sistema-nacional-de-cultura/
#
# 🎯 Total de textos coletados com sucesso: 995

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("clipping_faciap_textos.db")
df = pd.read_sql_query("SELECT * FROM textos_completos", conn)
conn.close()

df.head()
# Out:
#    id                                                url  \
# 0   1  https://www.camara.leg.br/noticias/1182032-com...
# 1   2  https://www.camara.leg.br/noticias/1182017-com...
# 2   3  https://www12.senado.leg.br/noticias/materias/...
# 3   4  https://www.camara.leg.br/noticias/1181948-pro...
# 4   5  https://www12.senado.leg.br/noticias/materias/...
#
#                    fonte                                             titulo  \
# 0  CÃ¢mara dos Deputados  ComissÃ£o aprova proposta de estÃ­mulo fiscal ...
# 1  CÃ¢mara dos Deputados  ComissÃ£o aprova projeto que obriga serviÃ§os ...
# 2         Senado Federal  Sancionada homenagem a JosÃ© Pereira da Silva ...
# 3  CÃ¢mara dos Deputados  Projeto cria novo marco legal do transporte in...
# 4         Senado Federal  Senado deve analisar Fundo Social do prÃ©-sal ...
#
#        data_publicacao                                     texto_completo  \
# 0  2025-07-18 18:28:00  Projeto será analisado por outras três comissõ...
# 1  2025-07-18 18:09:00  Vinicius Loures/Câmara dos DeputadosDeputado T...
# 2  2025-07-18 17:38:00  Passa a se chamar Deputado José Pereira da Sil...
# 3  2025-07-18 17:31:00  Kayo Magalhães / Câmara dos DeputadosLuiz Gast...
# 4  2025-07-18 17:16:00  O Senado deve examinar no segundo semestre o p...
#
#    num_palavras                 coletado_em
# 0           556  2025-07-21T05:01:54.805323
# 1           602  2025-07-21T05:01:55.394872
# 2           179  2025-07-21T05:01:56.367900
# 3          1428  2025-07-21T05:01:58.645875
# 4          1397  2025-07-21T05:01:59.510614

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 27.4 MB/s eta 0:00:00
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import sqlite3
import pandas as pd
import spacy
import unicodedata
import re
from datetime import datetime

# Carrega modelo spaCy para lematização em português
nlp = spacy.load("pt_core_news_sm")

# Funções de pré-processamento

def limpar_texto(texto):
    texto = texto.lower()
    texto = unicodedata.normalize('NFKD', texto).encode('ASCII', 'ignore').decode('utf-8')
    texto = re.sub(r'[\W_]+', ' ', texto)  # Remove pontuação
    return texto.strip()

def lematizar_texto(texto):
    doc = nlp(texto)
    return ' '.join([token.lemma_ for token in doc if not token.is_stop])

# Carrega dicionário de palavras-chave
df_dict = pd.read_csv("dicionario_faciap.csv", sep=';')
df_dict['palavra_chave'] = df_dict['palavra_chave'].str.lower()

# Converte vírgulas para pontos nas colunas numéricas
df_dict['peso_risco'] = df_dict['peso_risco'].astype(str).str.replace(',', '.').astype(float)
df_dict['peso_interesse'] = df_dict['peso_interesse'].astype(str).str.replace(',', '.').astype(float)

# Conecta ao banco de dados
conn = sqlite3.connect("clipping_faciap_textos.db")
df_noticias = pd.read_sql_query("SELECT * FROM textos_completos", conn)

resultados = []

# Calcula o score para cada notícia
for _, row in df_noticias.iterrows():
    texto_bruto = row['texto_completo']
    texto = limpar_texto(texto_bruto)
    texto_lema = lematizar_texto(texto)

    score_risco = 0
    score_interesse = 0
    palavras_ativadas = []
    eixo_dominante = None

    for _, item in df_dict.iterrows():
        termo = item['palavra_chave']
        ocorrencias = texto_lema.count(termo.lower())
        if ocorrencias > 0:
            score_risco += ocorrencias * float(item['peso_risco'])
            score_interesse += ocorrencias * float(item['peso_interesse'])
            palavras_ativadas.append(termo)

    if palavras_ativadas:
        # Eixo mais frequente entre as palavras ativadas
        eixos_filtrados = df_dict[df_dict['palavra_chave'].isin(palavras_ativadas)]['eixo_temat']
        eixo_dominante = eixos_filtrados.mode().iloc[0] if not eixos_filtrados.empty else None

    resultados.append({
        'noticia_id': row['id'],
        'score_risco': score_risco,
        'score_interesse': score_interesse,
        'palavras_chave': ', '.join(set(palavras_ativadas)),
        'categoria': eixo_dominante,
        'data_avaliacao': datetime.now().isoformat()
    })

# Cria nova tabela de scores e salva
df_resultados = pd.DataFrame(resultados)
df_resultados.to_sql("scores_faciap", conn, if_exists='replace', index=False)
conn.commit()
conn.close()

print("✅ Cálculo de Score FACIAP concluído e salvo no banco de dados.")
# Out:
# ✅ Cálculo de Score FACIAP concluído e salvo no banco de dados.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("clipping_faciap_textos.db")
df_scores = pd.read_sql_query("SELECT * FROM scores_faciap", conn)
conn.close()

df_scores.to_csv("scores_faciap_resultados.csv", index=False, encoding='utf-8')

# %%
import sqlite3
conn = sqlite3.connect("clipping_faciap_textos.db")
cursor = conn.cursor()

# Lista todas as tabelas
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tabelas = cursor.fetchall()
print("Tabelas:", tabelas)

# Para cada tabela, mostra a estrutura
for tabela in tabelas:
    nome_tabela = tabela[0]
    cursor.execute(f"PRAGMA table_info({nome_tabela})")
    colunas = cursor.fetchall()
    print(f"\nEstrutura da tabela '{nome_tabela}':")
    for coluna in colunas:
        print(f"  {coluna[1]} ({coluna[2]})")

conn.close()
# Out:
# Tabelas: [('textos_completos',), ('sqlite_sequence',), ('scores_faciap',)]
#
# Estrutura da tabela 'textos_completos':
#   id (INTEGER)
#   url (TEXT)
#   fonte (TEXT)
#   titulo (TEXT)
#   data_publicacao (TEXT)
#   texto_completo (TEXT)
#   num_palavras (INTEGER)
#   coletado_em (TEXT)
#
# Estrutura da tabela 'sqlite_sequence':
#   name ()
#   seq ()
#
# Estrutura da tabela 'scores_faciap':
#   noticia_id (INTEGER)
#   score_risco (REAL)
#   score_interesse (REAL)
#   palavras_chave (TEXT)
#   categoria (TEXT)
#   data_avaliacao (TEXT)

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("clipping_faciap_textos.db")
df_amostra = pd.read_sql_query("SELECT * FROM textos_completos LIMIT 3", conn)
print(df_amostra.columns.tolist())
print(df_amostra.head())
conn.close()
# Out:
# ['id', 'url', 'fonte', 'titulo', 'data_publicacao', 'texto_completo', 'num_palavras', 'coletado_em']
#    id                                                url  \
# 0   1  https://www.camara.leg.br/noticias/1182032-com...
# 1   2  https://www.camara.leg.br/noticias/1182017-com...
# 2   3  https://www12.senado.leg.br/noticias/materias/...
#
#                    fonte                                             titulo  \
# 0  CÃ¢mara dos Deputados  ComissÃ£o aprova proposta de estÃ­mulo fiscal ...
# 1  CÃ¢mara dos Deputados  ComissÃ£o aprova projeto que obriga serviÃ§os ...
# 2         Senado Federal  Sancionada homenagem a JosÃ© Pereira da Silva ...
#
#        data_publicacao                                     texto_completo  \
# 0  2025-07-18 18:28:00  Projeto será analisado por outras três comissõ...
# 1  2025-07-18 18:09:00  Vinicius Loures/Câmara dos DeputadosDeputado T...
# 2  2025-07-18 17:38:00  Passa a se chamar Deputado José Pereira da Sil...
#
#    num_palavras                 coletado_em
# 0           556  2025-07-21T05:01:54.805323
# 1           602  2025-07-21T05:01:55.394872
# 2           179  2025-07-21T05:01:56.367900
